# %% [markdown]
# <h1 style="line-height: 1.3">W4111: Introduction to Databases $-$ NoSQL and Examples</h1>

# %% [markdown]
# ## Neo4J
#
# - Graphs have Nodes and Relationships.
#
#
# - The py2neo [_object-graph mapping_](https://py2neo.org/v3/ogm.html#py2neo.ogm.py2neo.ogm.GraphObject) packages simplifies mapping between Neo4j and Python objects. There is a good starter tutorial at [Medium](https://medium.com/neo4j/py2neo-v4-2bedc8afef2).
#
#
# - The sample Movie DB has Person and Movie, and some relationships.
#
#
# - You can represent this in Python with

# %%
from py2neo import Graph
from py2neo.ogm import GraphObject, Property, RelatedFrom, RelatedTo


graph = Graph("bolt://localhost:7687", auth=("neo4j", "neo4j"))


class Movie(GraphObject):
    __primarykey__ = "title"
    title = Property()
    tagline = Property()
    released = Property()
    actors = RelatedFrom("Person", "ACTED_IN")
    directors = RelatedFrom("Person", "DIRECTED")
    producers = RelatedFrom("Person", "PRODUCED")

class Person(GraphObject):
    __primarykey__ = "name"
    name = Property()
    born = Property()
    acted_in = RelatedTo(Movie)
    directed = RelatedTo(Movie)
    produced = RelatedTo(Movie)

# %% [markdown]
# - And some simple tests

# %%
def t1():
    x = graph.nodes.match("Person", name="Keanu Reeves").first()
    print(type(x))
    print('Born = ', x['born'])
    y = Person.wrap(x)
    print(y.born)
    print(y)

def t2():
    st = Person.match(graph).where("_.born = 1960")
    print("People born in 1960 and the movies they acted in:")
    for s in st:
        print(s.name, s.born)

        for m in s.acted_in:
            print("\t", m.title, m.released)

# %%
t1()
# Out:
# <class 'py2neo.data.Node'>
# Born =  1964
# 1964
# <Person name='Keanu Reeves'>

# %%
t2()
# Out:
# People born in 1960 and the movies they acted in:
# Hugo Weaving 1960
# 	 The Matrix 1999
# 	 The Matrix Reloaded 2003
# 	 The Matrix Revolutions 2003
# 	 Cloud Atlas 2012
# 	 V for Vendetta 2006
# Annabella Sciorra 1960
# 	 What Dreams May Come 1998
# John Goodman 1960
# 	 Speed Racer 2008
# Oliver Platt 1960
# 	 Frost/Nixon 2008
# 	 Bicentennial Man 1999

# %% [markdown]
# ## Homework 4
#
# ### Setup
#
# - Install Neo4j Community Edition. Do not install the desktop. Just install the server.
#
#
# - Add py2neo to your environments, if necessary.
#
#
# - Using PyCharm to develop and test your code is the best practice. You can copy the code into the notebook when done developing and testing.
#
#
# ### Concept
#
# - Load information from lahman2017.people, lahman2017.teams, lahman2017.appearances. The code for loading the database is below.
#
#
# - Add a Node type for _Fan._ __NOTE:__ You do not need to add a class unlike the pattern above.
#
#
# - Allow a Fan to follow other Fans, Comment on a Team and/or Player and response to Comments.
#
#
# ### Data Model
#
# - The loading function do not all of the data. The loaded is scoped by year range, which you will see in code below. (Loading the full database would create performance problems for you and require getting a licensed version).
#
#
# - Node Labels:
#     - Team: Core information loaded from Lahman 2017
#     - Player: Core information loaded from Lahman 2017
#     - Fan: New entity representing a baseball fan.
#     - Comment: A Fan made a comment on a team or player.
#
#
# - Relationships:
#     - Appeared: Represents the fact that a player "appeared" for a team in a year. Loaded from a small subset of Lahman 2017.
#     - Supports: A Fan supports a Team
#     - Follows: A Fan follows (the comments of) another Fan.
#     - CommentOn: Represents the relationship between a Comment and a Team/Player.
#     - CommentBy: Relationship between a Fan and Comment.
#     - ResponseTo: Indicates that a Comment is a ResponseTo a Comment.

# %% [markdown]
# ### HW4 Part 1: Implementation and Template

# %% [markdown]
# - There are two parts to HW4:
#     1. Simple social model and topics in Neo4j
#     2. API result cache for database query results using Redis. A section later in the notebook explains part 2.
#
#
# - HW4:
#     - Starts with a Python implementation template for a class _FanGraph._
#         - Contains many example methods.
#         - Placeholder for the methods that you need to implement.
#     - Some sample client code for creating and finding nodes and relationships.
#     - A few test cases to get you started and verify correctness. You need to implement a more complete set of tests.
#
#
# - HW4 tasks:
#     - Load the Neo4j database using the load functions below.
#     - Implement and test the incomplete methods (ones with "pass") in the template.
#
# ### Template

# %%
"""
This is the template. Do not execute.
"""

raise NotImplementedError("This is template fool! Do not run.")

from py2neo import data, Graph, NodeMatcher, Node, Relationship, RelationshipMatcher

"""
See https://py2neo.org/v4/
"""

"""
NOTE:
    1. I did some basic testing, debugging, etc. but there may be errors.
    2. You can complain about the errors if you want but my response will be, "No Template for You!"
"""

import json
import uuid


class FanGraph(object):
    """
    This object provides a set of helper methods for creating and retrieving nodes and relationships from
    a Neo4j database holding information about players, teams, fans, comments and their relationships.
    """

    # Note:
    # I tend to avoid object mapping frameworks. Object mapping frameworks are fun in the beginning
    # but tend to be annoying after a while. So, I did not create types Player, Team, etc.
    #


    # Connects to the DB and sets a Graph instance variable.
    # Also creates a NodeMatcher and RelationshipMatcher, which are a py2neo framework classes.
    def __init__(self, auth=('neo4j', 'neo4j'), host='localhost', port=7687, secure=False, ):
        self._graph = Graph(secure=secure,
                            bolt=True,
                            auth=auth,
                            host=host,
                            port=port)
        self._node_matcher = NodeMatcher(self._graph)
        self._relationship_matcher = RelationshipMatcher(self._graph)

    def run_q(self, qs, args):
        """

        :param qs: Query string that may have {} slots for parameters.
        :param args: Dictionary of parameters to insert into query string.
        :return:  Result of the query, which executes as a single, standalone transaction.
        """
        try:
            tx = self._graph.begin(autocommit=False)
            result = self._graph.run(qs, args)
            return result
        except Exception as e:
            print("Run exaception = ", e)

    def run_match(self, labels=None, properties=None):
        """
        Uses a NodeMatcher to find a node matching a "template."
        :param labels: A list of labels that the node must have.
        :param properties: A dictionary of {property_name: property_value} defining the template that the
            node must match.
        :return: An array of Node objects matching the pattern.
        """
        # ut.debug_message("Labels = ", labels)
        # ut.debug_message("Properties = ", json.dumps(properties))

        if labels is not None and properties is not None:
            result = self._node_matcher.match(labels, **properties)
        elif labels is not None and properties is None:
            result = self._node_matcher.match(labels)
        elif labels is None and properties is not None:
            result = self._node_matcher.match(**properties)
        else:
            raise ValueError("Invalid request. Labels and properties cannot both be None.")

        # Convert NodeMatch data into a simple list of Nodes.
        full_result = []
        for r in result:
            full_result.append(r)

        return full_result

    def find_nodes_by_template(self, tmp):
        """

        :param tmp: A template defining the label and properties for Nodes to return. An
         example is { "label": "Fan", "template" { "last_name": "Ferguson", "first_name": "Donald" }}
        :return: A list of Nodes matching the template.
        """
        labels = tmp.get('label', None)
        props = tmp.get("template", None)
        result = self.run_match(labels=labels, properties=props)
        return result

    # Create and save a new node for  a 'Fan.'
    def create_fan(self, uni, last_name, first_name):
        """

        :param uni: uni
        :param last_name: Obvious
        :param first_name: Obvious
        :return: Node created.

        NOTE: This does not check uni uniqueness. We could do using transactions or setting a constraint
        on the database.
        """
        n = Node("Fan", uni=uni, last_name=last_name, first_name=first_name)
        tx = self._graph.begin(autocommit=True)
        tx.create(n)
        return n

    # Given a UNI, return the node for the Fan.
    def get_fan(self, uni):
        n = self.find_nodes_by_template({"label": "Fan", "template": {"uni": uni}})
        if n is not None and len(n) > 0:
            # I should throw an exception here if there is more than 1.
            n = n[0]
        else:
            n = None

        return n

    def create_player(self, player_id, last_name, first_name):
        n = Node("Player", player_id=player_id, last_name=last_name, first_name=first_name)
        tx = self._graph.begin(autocommit=True)
        tx.create(n)
        return n

    def get_player(self, player_id):
        n = self.find_nodes_by_template({"label": "Player", "template": {"player_id": player_id}})
        if n is not None and len(n) > 0:
            n = n[0]
        else:
            n = None

        return n

    def create_team(self, team_id, team_name):
        n = Node("Team", team_id=team_id, team_name=team_name)
        tx = self._graph.begin(autocommit=True)
        tx.create(n)
        return n

    def get_team(self, team_id):
        n = self.find_nodes_by_template({"label": "Team", "template": {"team_id": team_id}})
        if n is not None and len(n) > 0:
            n = n[0]
        else:
            n = None

        return n

    def create_supports(self, uni, team_id):
        """
        Create a SUPPORTS relationship from a Fan to a Team.
        :param uni: The UNI for a fan.
        :param team_id: An ID for a team.
        :return: The created SUPPORTS relationship from the Fan to the Team
        """
        f = self.get_fan(uni)
        t = self.get_team(team_id)
        r = Relationship(f, "SUPPORTS", t)
        tx = self._graph.begin(autocommit=True)
        tx.create(r)
        return r

    def get_appearance(self, player_id, team_id, year_id):
        """
        Get the information about appearances for a player and team.
        :param player_id: player_id
        :param team_id: team_id
        :param year_id: The year for getting appearances.
        :return:
        """
        try:
            # Get the Nodes at the ends of the relationship representing appearances.
            p = self.get_player(player_id)
            t = self.get_team(team_id)

            # Run a match looking for relationships of a specific type linking the nodes.
            rm = self._graph.match(nodes=[p, t], r_type="APPEARED")
            result = []

            # If there is a list of relationships.
            if rm is not None:
                for r in rm:

                    # The type will be a class APPEARED() because of the OO mapping.
                    node_type = type(r).__name__
                    year = r['year']

                    # If the type and year are correct, add to result
                    if node_type == "APPEARED" and (year == year_id or year_id is None):
                        result.append(r)

                return result
            else:
                return None
        except Exception as e:
            print("get_appearance: Exception e = ", e)
            raise e

    # Create an APPEARED relationship from a player to a Team
    def create_appearance_all(self, player_id, team_id, year, games):
        """

        :param player_id: O
        :param team_id:
        :param year:
        :param games:
        :return:
        """
        try:
            tx = self._graph.begin(autocommit=False)
            q = "match (n:Player {player_id: '" + player_id + "'}), " + \
                "(t:Team {team_id: '" + team_id + "'}) " + \
                "create (n)-[r:APPEARED { games: " + str(games) + ", year : " + str(year) + \
                "}]->(t)"
            result = self._graph.run(q)
            tx.commit()
        except Exception as e:
            print("create_appearances: exception = ", e)

    # Create a FOLLOWS relationship from a Fan to another Fan.
    def create_follows(self, follower, followed):
        f = self.get_fan(follower)
        t = self.get_fan(followed)
        r = Relationship(f, "FOLLOWS", t)
        tx = self._graph.begin(autocommit=True)
        tx.create(r)

    def get_comment(self, comment_id):
        """

        :param comment_id: Comment ID
        :return: Comment
        """
        pass

    def create_comment(self, uni, comment, team_id=None, player_id=None):
        """
        Creates a comment
        :param uni: The UNI for the Fan making the comment.
        :param comment: A simple string.
        :param team_id: A valid team ID or None. team_id and player_id cannot BOTH be None.
        :param player_id: A valid player ID or None
        :return: The Node representing the comment.
        """
        

    def create_sub_comment(self, uni, origin_comment_id, comment):
        """
        Create a sub-comment (response to a comment or response) and links with parent in thread.
        :param uni: ID of the Fan making the comment.
        :param origin_comment_id: Id of the comment to which this is a response.
        :param comment: Comment string
        :return: Created comment.
        """
        pass

    def get_sub_comments(self, comment_id):
        """

        :param comment_id: The unique ID of the comment.
        :return: The sub-comments.
        """
        pass

    def get_player_comments(self, player_id):
        """
        Gets all of the comments associated with a player, Also returns the Nodes for people making the comments.
        :param player_id: ID of the player.
        :return: Graph containing comment, comment streams and commenters.
        """
        pass

    def get_team_comments(self, team_id):
        """
        Gets all of the comments associated with a team.  Also returns the Nodes for people making the comments.
        :param player_id: ID of the team.
        :return: Graph containing comment, comment streams and commenters.
        """
        pass

    def get_players_by_team(self, team_id, yearid):
        """
        
        :param team_id: The ID of a team.
        :param yearid: A year.
        :return: Returns the players who played for the team in the year.
        """
        pass
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-98-6d11bd2940c1> in <module>()
#       3 """
#       4
# ----> 5 raise NotImplementedError("This is ")
#       6
#       7 from py2neo import data, Graph, NodeMatcher, Node, Relationship, RelationshipMatcher
#
# NotImplementedError: This is

# %% [markdown]
# ### Tests and Examples
#
# #### Setup The Environment
#
# - These tests come from my solution to the homework. I have to direct the notebook's Python kernel to my implementation, which completes the template above.

# %%
# I run my tests off of the "real" implementation that I have
# hidden somewhere.
import sys
sys.path.append(
    '/Users/donaldferguson/Dropbox/ColumbiaCourse/Courses/W4111New/w4111-Databases/HW_Solutions/HW4')

# %%
import social_graph.fan_comment as fc
import json
import pandas as pd

pd.set_option('display.width', 132)

# %%
fg = fc.FanGraph(
                  host="localhost",
                  port=7687,
                  secure=False)

# %%
print("fg = ", fg)
# Out:
# fg =  <social_graph.fan_comment.FanGraph object at 0x1053c7a90>

# %% [markdown]
# #### Simple Tests and Examples
#
# ##### Query Example

# %%
def t1(name):
    """
    Find all the movies that a person with name 'name' is related to.
    Return information as a Pandas data frame.
    """
    
    # The match is (Person)-[any relationship]->(Movie)
    # Person name must be the passed {name}.
    # Return a list of dictionaries of the attributes/values.
    #
    qs = "match (t:Person)-[r]->(t2:Movie) " + \
    " where t.name={name} " + \
    " return t.name, t2.title, t2.released, r.roles"
    
    # Set the name parameter for the query
    ag = {"name": name}
    
    # Use the handy, dandy run_q method on FanGraph
    r = fg.run_q(qs, ag)
    
    # Convert the result into a DataFrame
    x = pd.DataFrame(r.data())
    
    # Make sure the columns are in the "right" order. 
    # Python dicts are unordered, which means the data frame's columns
    # might be in a weird order.
    x = x[['t.name', 't2.title', 't2.released', 'r.roles']]
    return x

# %%
# Find Tom Hanks
x = t1('Tom Hanks')
print(x)
# Out:
#        t.name                t2.title  t2.released                                            r.roles
# 0   Tom Hanks          The Green Mile         1999                                    [Paul Edgecomb]
# 1   Tom Hanks               Cast Away         2000                                     [Chuck Noland]
# 2   Tom Hanks               Apollo 13         1995                                       [Jim Lovell]
# 3   Tom Hanks    Charlie Wilson's War         2007                              [Rep. Charlie Wilson]
# 4   Tom Hanks   A League of Their Own         1992                                      [Jimmy Dugan]
# 5   Tom Hanks       The Polar Express         2004  [Hero Boy, Father, Conductor, Hobo, Scrooge, S...
# 6   Tom Hanks    Sleepless in Seattle         1993                                      [Sam Baldwin]
# 7   Tom Hanks         You've Got Mail         1998                                          [Joe Fox]
# 8   Tom Hanks  Joe Versus the Volcano         1990                                        [Joe Banks]
# 9   Tom Hanks       That Thing You Do         1996                                               None
# 10  Tom Hanks       That Thing You Do         1996                                        [Mr. White]
# 11  Tom Hanks             Cloud Atlas         2012  [Zachry, Dr. Henry Goose, Isaac Sachs, Dermot ...
# 12  Tom Hanks       The Da Vinci Code         2006                               [Dr. Robert Langdon]

# %% [markdown]
# ##### Create a Fan

# %%
def test_create_fan():
    r = fg.create_fan(uni="dff99999", last_name="Vader", first_name="Donald")
    return r

# %%
f = test_create_fan()
print("Create returned ...", f)
print("The type is ... ", type(f))
# Out:
# Create returned ... (_71732:Fan {first_name: 'Donald', last_name: 'Vader', uni: 'dff99999'})
# The type is ...  <class 'py2neo.data.Node'>

# %% [markdown]
# - Notice that this returns a py2neo Python class Node that holds the data.
#
#
# - Let's probe this a little.

# %%
# Get the labels.
f.labels
# Out:
# :Fan

# %%
f.keys()
# Out:
# dict_keys(['uni', 'last_name', 'first_name'])

# %%
f.items()
# Out:
# dict_items([('uni', 'dff99999'), ('last_name', 'Vader'), ('first_name', 'Donald')])

# %%
for k,v in f.items():
    print(k, ": ", v)
# Out:
# uni :  dff999
# last_name :  Vader
# first_name :  Donald

# %% [markdown]
# - The Node is 'sort of' a dictionary.
#
#
# - What are all the attributes? What did we actually get? Look in the documentation.
#
#
# - Or use the Python function.

# %%
# Load the introspection/reflection functions.
import inspect

# Get the class object for the Fan (https://docs.python.org/3/tutorial/classes.html#class-objects)
cf = f.__class__

# Get the "method resolution order," i.e. the inheritance hierarchy.
inspect.getmro(cf)
# Out:
# (py2neo.data.Node,
#  py2neo.data.Entity,
#  py2neo.data.PropertyDict,
#  dict,
#  py2neo.data.Walkable,
#  py2neo.data.Subgraph,
#  object)

# %%
# Get all of the attributes and methods. The __xxx__ are internal. The others are attributes and functions you can
# and which are documented.
dir(f)
# Out:
# ['_Node__ensure_labels',
#  '_Subgraph__nodes',
#  '_Subgraph__relationships',
#  '_Walkable__sequence',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__db_create__',
#  '__db_delete__',
#  '__db_exists__',
#  '__db_merge__',
#  '__db_pull__',
#  '__db_push__',
#  '__db_separate__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__uuid__',
#  '__walk__',
#  '__weakref__',
#  '__xor__',
#  '_labels',
#  '_remote_labels',
#  '_stale',
#  'add_label',
#  'cast',
#  'clear',
#  'clear_labels',
#  'copy',
#  'end_node',
#  'fromkeys',
#  'get',
#  'graph',
#  'has_label',
#  'identity',
#  'items',
#  'keys',
#  'labels',
#  'nodes',
#  'pop',
#  'popitem',
#  'relationships',
#  'remove_label',
#  'setdefault',
#  'start_node',
#  'types',
#  'update',
#  'update_labels',
#  'values']

# %%
q = "match (p {name: 'Tom Hanks'})-[r:ACTED_IN]->(m) return p,r,m"
r = fg.run_q(q, None)
print(r)
# Out:
# <py2neo.database.Cursor object at 0x109873898>

# %%
# Cursor is similar to cursor in other databases.
for t in r:
    print(t)
# Out:
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Paul Edgecomb']}]->(_17540) m=(_17540:Movie {released: 1999, tagline: "Walk a mile you'll never forget.", title: 'The Green Mile'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Chuck Noland']}]->(_17560) m=(_17560:Movie {released: 2000, tagline: 'At the edge of the world, his journey begins.', title: 'Cast Away'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Jim Lovell']}]->(_17554) m=(_17554:Movie {released: 1995, tagline: 'Houston, we have a problem.', title: 'Apollo 13'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Rep. Charlie Wilson']}]->(_17569) m=(_17569:Movie {released: 2007, tagline: "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", title: "Charlie Wilson's War"})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Jimmy Dugan']}]->(_17572) m=(_17572:Movie {released: 1992, tagline: 'Once in a lifetime you get a chance to do something different.', title: 'A League of Their Own'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Hero Boy', 'Father', 'Conductor', 'Hobo', 'Scrooge', 'Santa Claus']}]->(_17571) m=(_17571:Movie {released: 2004, tagline: 'This Holiday Season\u2026 Believe', title: 'The Polar Express'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Sam Baldwin']}]->(_17483) m=(_17483:Movie {released: 1993, tagline: 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?', title: 'Sleepless in Seattle'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Joe Fox']}]->(_17477) m=(_17477:Movie {released: 1998, tagline: 'At odds in life... in love on-line.', title: "You've Got Mail"})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Joe Banks']}]->(_17488) m=(_17488:Movie {released: 1990, tagline: 'A story of love, lava and burning desire.', title: 'Joe Versus the Volcano'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Mr. White']}]->(_17495) m=(_17495:Movie {released: 1996, tagline: 'In every life there comes a time when that thing you dream becomes that thing you do', title: 'That Thing You Do'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Zachry', 'Dr. Henry Goose', 'Isaac Sachs', 'Dermot Hoggins']}]->(_17515) m=(_17515:Movie {released: 2012, tagline: 'Everything is connected', title: 'Cloud Atlas'})>
# <Record p=(_17481:Person {born: 1956, name: 'Tom Hanks'}) r=(Tom Hanks)-[:ACTED_IN {roles: ['Dr. Robert Langdon']}]->(_17521) m=(_17521:Movie {released: 2006, tagline: 'Break The Codes', title: 'The Da Vinci Code'})>

# %%
print(r[0])
print(type(r[0]))
print("\n", r[1])
print(type(r[1]))
print("\n", r[2])
print(type(r[2]))
print("\n", r[3])
print(type(r[3]))
# Out:
# (_17481:Person {born: 1956, name: 'Tom Hanks'})
# <class 'py2neo.data.Node'>
#
#  (Tom Hanks)-[:ACTED_IN {roles: ['Dr. Robert Langdon']}]->(_17521)
# <class 'py2neo.data.ACTED_IN'>
#
#  (_17521:Movie {released: 2006, tagline: 'Break The Codes', title: 'The Da Vinci Code'})
# <class 'py2neo.data.Node'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-0e6837329581> in <module>()
#       5 print("\n", r[2])
#       6 print(type(r[2]))
# ----> 7 print("\n", r[3])
#       8 print(type(r[3]))
#
# ~/anaconda3/lib/python3.6/site-packages/py2neo/database.py in __getitem__(self, key)
#    1106
#    1107     def __getitem__(self, key):
# -> 1108         return self._current[key]
#    1109
#    1110     @property
#
# ~/anaconda3/lib/python3.6/site-packages/py2neo/data.py in __getitem__(self, key)
#     109             values = super(Record, self).__getitem__(key)
#     110             return self.__class__(zip(keys, values))
# --> 111         index = self.index(key)
#     112         if 0 <= index < len(self):
#     113             return super(Record, self).__getitem__(index)
#
# ~/anaconda3/lib/python3.6/site-packages/py2neo/data.py in index(self, key)
#     144             if 0 <= key < len(self.__keys):
#     145                 return key
# --> 146             raise IndexError(key)
#     147         elif isinstance(key, string_types):
#     148             try:
#
# IndexError: 3

# %%
r.forward()
# Out:
# 0

# %%
print(r[0])
print(type(r[0]))
print("\n", r[1])
print(type(r[1]))
print("\n", r[2])
print(type(r[2]))
# Out:
# (_17481:Person {born: 1956, name: 'Tom Hanks'})
# <class 'py2neo.data.Node'>
#
#  (Tom Hanks)-[:ACTED_IN {roles: ['Dr. Robert Langdon']}]->(_17521)
# <class 'py2neo.data.ACTED_IN'>
#
#  (_17521:Movie {released: 2006, tagline: 'Break The Codes', title: 'The Da Vinci Code'})
# <class 'py2neo.data.Node'>

# %% [markdown]
# ##### Generic Node find_by_template()
#
# - It should not surprise you that our graph object has this function.
#     - We had it for CSVDataTable.
#     - We had it for RDBDataTable.
#     - We have it here.
#
#
# - We will "sort of" have for Redis

# %%
def t_find_by_template():
    
    # Test the find_by_template() function.
    # Template includes the Label, which is a slightly different for than the find_by_template() format.
    # we previously used.
    # The Label replaces the "table name." There are no tables in Neo4j
    tmp = {"label": "Person", "template": {"name": "Tom Hanks"}}
    r = fg.find_nodes_by_template(tmp)
    return r

# %%
n = t_find_by_template()
print(n)
print(type(n))
# Out:
# [(_17481:Person {born: 1956, name: 'Tom Hanks'})]
# <class 'list'>

# %%
from py2neo import NodeMatcher

# Should not do this, but what the heck.
nm = fg._node_matcher
n2 = nm.match(name="Tom Hanks")
n2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-07f2ce122870> in <module>()
# ----> 1 Node(n[0])
#
# NameError: name 'Node' is not defined

# %%
y = n2.first()
print(y)
print(type(y))
# Out:
# (_17481:Person {born: 1956, name: 'Tom Hanks'})
# <class 'py2neo.data.Node'>

# %%
from py2neo import NodeMatcher

# Should not do this, but what the heck.
rm = fg._relationship_matcher
r2 = rm.match([y])
r2

# %%
for rr in r2:
    print(rr)
# Out:
# (Tom Hanks)-[:ACTED_IN {roles: ['Paul Edgecomb']}]->(_17540)
# (Tom Hanks)-[:ACTED_IN {roles: ['Chuck Noland']}]->(_17560)
# (Tom Hanks)-[:ACTED_IN {roles: ['Jim Lovell']}]->(_17554)
# (Tom Hanks)-[:ACTED_IN {roles: ['Rep. Charlie Wilson']}]->(_17569)
# (Tom Hanks)-[:ACTED_IN {roles: ['Jimmy Dugan']}]->(_17572)
# (Tom Hanks)-[:ACTED_IN {roles: ['Hero Boy', 'Father', 'Conductor', 'Hobo', 'Scrooge', 'Santa Claus']}]->(_17571)
# (Tom Hanks)-[:ACTED_IN {roles: ['Sam Baldwin']}]->(_17483)
# (Tom Hanks)-[:ACTED_IN {roles: ['Joe Fox']}]->(_17477)
# (Tom Hanks)-[:ACTED_IN {roles: ['Joe Banks']}]->(_17488)
# (Tom Hanks)-[:DIRECTED {}]->(_17495)
# (Tom Hanks)-[:ACTED_IN {roles: ['Mr. White']}]->(_17495)
# (Tom Hanks)-[:ACTED_IN {roles: ['Zachry', 'Dr. Henry Goose', 'Isaac Sachs', 'Dermot Hoggins']}]->(_17515)
# (Tom Hanks)-[:ACTED_IN {roles: ['Dr. Robert Langdon']}]->(_17521)

# %% [markdown]
# #### Load Data
#
# - __NOTE:__ I previously ran this code. It is just here for teaching purposes and to allow you to use it.
#
#
# - There are tests below using FanGraph functions to explore the loaded data.

# %%
raise NotImplementedError("Do not run this code fool!")

cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuserdbuser',
                             db='lahman2017',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

fg = FanGraph(auth=('neo4j', 'XXXXX'),
                  host="localhost",
                  port=7687,
                  secure=False)

# %%
raise NotImplementedError("Do not run this code fool!")

def load_players():
    """
    Load a subset of the player data. We only load a subset of the columns and the rows.
    """

    q = "SELECT playerID, nameLast, nameFirst FROM People where  " + \
        "exists (select * from appearances where appearances.playerID = " +
        " people.playerID and yearID >= 2010)"

    curs = cnx.cursor()
    curs.execute(q)

    # This is an example of using a cursor. We could have used fetchall() but
    # I wanted to give you an example of iterating using a cursor.
    r = curs.fetchone()
    cnt = 0
    
    # Loop until we are out of rows.
    while r is not None:
        print(r)
        cnt += 1
        if r is not None:
            p = fg.create_player(player_id=r['playerID'], last_name=r['nameLast'], first_name=r['nameFirst'])
            print("Created player = ", p)

        r = curs.fetchone()

    print("Loaded ", cnt, "records.")

# %%
raise NotImplementedError("Do not run this code fool!")

load_players()
# Out:
# {'playerID': 'aardsda01', 'nameLast': 'Aardsma', 'nameFirst': 'David'}
# Created player =  (_22569:Player {first_name: 'David', last_name: 'Aardsma', player_id: 'aardsda01'})
# {'playerID': 'abadfe01', 'nameLast': 'Abad', 'nameFirst': 'Fernando'}
# Created player =  (_22574:Player {first_name: 'Fernando', last_name: 'Abad', player_id: 'abadfe01'})
# {'playerID': 'abreubo01', 'nameLast': 'Abreu', 'nameFirst': 'Bobby'}
# Created player =  (_22573:Player {first_name: 'Bobby', last_name: 'Abreu', player_id: 'abreubo01'})
# {'playerID': 'abreujo02', 'nameLast': 'Abreu', 'nameFirst': 'Jose'}
# Created player =  (_22572:Player {first_name: 'Jose', last_name: 'Abreu', player_id: 'abreujo02'})
# {'playerID': 'abreuju01', 'nameLast': 'Abreu', 'nameFirst': 'Juan'}
# Created player =  (_22571:Player {first_name: 'Juan', last_name: 'Abreu', player_id: 'abreuju01'})
# {'playerID': 'abreuto01', 'nameLast': 'Abreu', 'nameFirst': 'Tony'}
# Created player =  (_22570:Player {first_name: 'Tony', last_name: 'Abreu', player_id: 'abreuto01'})
# {'playerID': 'accarje01', 'nameLast': 'Accardo', 'nameFirst': 'Jeremy'}
# Created player =  (_22581:Player {first_name: 'Jeremy', last_name: 'Accardo', player_id: 'accarje01'})
# {'playerID': 'aceveal01', 'nameLast': 'Aceves', 'nameFirst': 'Alfredo'}
# Created player =  (_22567:Player {first_name: 'Alfredo', last_name: 'Aceves', player_id: 'aceveal01'})
# {'playerID': 'achteaj01', 'nameLast': 'Achter', 'nameFirst': 'A. J.'}
# Created player =  (_22584:Player {first_name: 'A. J.', last_name: 'Achter', player_id: 'achteaj01'})
# {'playerID': 'ackledu01', 'nameLast': 'Ackley', 'nameFirst': 'Dustin'}
# Created player =  (_22585:Player {first_name: 'Dustin', last_name: 'Ackley', player_id: 'ackledu01'})
# {'playerID': 'acostma01', 'nameLast': 'Acosta', 'nameFirst': 'Manny'}
# Created player =  (_22586:Player {first_name: 'Manny', last_name: 'Acosta', player_id: 'acostma01'})
# {'playerID': 'adamecr01', 'nameLast': 'Adames', 'nameFirst': 'Cristhian'}
# Created player =  (_22587:Player {first_name: 'Cristhian', last_name: 'Adames', player_id: 'adamecr01'})
# {'playerID': 'adamsau01', 'nameLast': 'Adams', 'nameFirst': 'Austin'}
# Created player =  (_22588:Player {first_name: 'Austin', last_name: 'Adams', player_id: 'adamsau01'})
# {'playerID': 'adamsau02', 'nameLast': 'Adams', 'nameFirst': 'Austin'}
# Created player =  (_22589:Player {first_name: 'Austin', last_name: 'Adams', player_id: 'adamsau02'})
# {'playerID': 'adamsda02', 'nameLast': 'Adams', 'nameFirst': 'David'}
# Created player =  (_22590:Player {first_name: 'David', last_name: 'Adams', player_id: 'adamsda02'})
# {'playerID': 'adamsla01', 'nameLast': 'Adams', 'nameFirst': 'Lane'}
# Created player =  (_22591:Player {first_name: 'Lane', last_name: 'Adams', player_id: 'adamsla01'})
# {'playerID': 'adamsma01', 'nameLast': 'Adams', 'nameFirst': 'Matt'}
# Created player =  (_22592:Player {first_name: 'Matt', last_name: 'Adams', player_id: 'adamsma01'})
# {'playerID': 'adamsmi03', 'nameLast': 'Adams', 'nameFirst': 'Mike'}
# Created player =  (_22593:Player {first_name: 'Mike', last_name: 'Adams', player_id: 'adamsmi03'})
# {'playerID': 'adamsry01', 'nameLast': 'Adams', 'nameFirst': 'Ryan'}
# Created player =  (_22594:Player {first_name: 'Ryan', last_name: 'Adams', player_id: 'adamsry01'})
# {'playerID': 'adcocna01', 'nameLast': 'Adcock', 'nameFirst': 'Nathan'}
# Created player =  (_22595:Player {first_name: 'Nathan', last_name: 'Adcock', player_id: 'adcocna01'})
# {'playerID': 'adducji02', 'nameLast': 'Adduci', 'nameFirst': 'Jim'}
# Created player =  (_22596:Player {first_name: 'Jim', last_name: 'Adduci', player_id: 'adducji02'})
# {'playerID': 'adlemti01', 'nameLast': 'Adleman', 'nameFirst': 'Tim'}
# Created player =  (_22597:Player {first_name: 'Tim', last_name: 'Adleman', player_id: 'adlemti01'})
# {'playerID': 'adriaeh01', 'nameLast': 'Adrianza', 'nameFirst': 'Ehire'}
# Created player =  (_22598:Player {first_name: 'Ehire', last_name: 'Adrianza', player_id: 'adriaeh01'})
# {'playerID': 'affelje01', 'nameLast': 'Affeldt', 'nameFirst': 'Jeremy'}
# Created player =  (_22599:Player {first_name: 'Jeremy', last_name: 'Affeldt', player_id: 'affelje01'})
# {'playerID': 'aguilje01', 'nameLast': 'Aguilar', 'nameFirst': 'Jesus'}
# Created player =  (_22600:Player {first_name: 'Jesus', last_name: 'Aguilar', player_id: 'aguilje01'})
# {'playerID': 'ahmedni01', 'nameLast': 'Ahmed', 'nameFirst': 'Nick'}
# Created player =  (_22601:Player {first_name: 'Nick', last_name: 'Ahmed', player_id: 'ahmedni01'})
# {'playerID': 'albaljo01', 'nameLast': 'Albaladejo', 'nameFirst': 'Jonathan'}
# Created player =  (_22602:Player {first_name: 'Jonathan', last_name: 'Albaladejo', player_id: 'albaljo01'})
# {'playerID': 'alberan01', 'nameLast': 'Albers', 'nameFirst': 'Andrew'}
# Created player =  (_22603:Player {first_name: 'Andrew', last_name: 'Albers', player_id: 'alberan01'})
# {'playerID': 'alberha01', 'nameLast': 'Alberto', 'nameFirst': 'Hanser'}
# Created player =  (_22604:Player {first_name: 'Hanser', last_name: 'Alberto', player_id: 'alberha01'})
# {'playerID': 'alberma01', 'nameLast': 'Albers', 'nameFirst': 'Matt'}
# Created player =  (_22605:Player {first_name: 'Matt', last_name: 'Albers', player_id: 'alberma01'})
# {'playerID': 'albieoz01', 'nameLast': 'Albies', 'nameFirst': 'Ozzie'}
# Created player =  (_22606:Player {first_name: 'Ozzie', last_name: 'Albies', player_id: 'albieoz01'})
# {'playerID': 'albural01', 'nameLast': 'Alburquerque', 'nameFirst': 'Al'}
# Created player =  (_22607:Player {first_name: 'Al', last_name: 'Alburquerque', player_id: 'albural01'})
# {'playerID': 'alcanar01', 'nameLast': 'Alcantara', 'nameFirst': 'Arismendy'}
# Created player =  (_22608:Player {first_name: 'Arismendy', last_name: 'Alcantara', player_id: 'alcanar01'})
# {'playerID': 'alcanra01', 'nameLast': 'Alcantara', 'nameFirst': 'Raul'}
# Created player =  (_22609:Player {first_name: 'Raul', last_name: 'Alcantara', player_id: 'alcanra01'})
# {'playerID': 'alcansa01', 'nameLast': 'Alcantara', 'nameFirst': 'Sandy'}
# Created player =  (_22610:Player {first_name: 'Sandy', last_name: 'Alcantara', player_id: 'alcansa01'})
# {'playerID': 'alcanvi01', 'nameLast': 'Alcantara', 'nameFirst': 'Victor'}
# Created player =  (_22611:Player {first_name: 'Victor', last_name: 'Alcantara', player_id: 'alcanvi01'})
# {'playerID': 'aldrico01', 'nameLast': 'Aldridge', 'nameFirst': 'Cory'}
# Created player =  (_22612:Player {first_name: 'Cory', last_name: 'Aldridge', player_id: 'aldrico01'})
# {'playerID': 'alexasc01', 'nameLast': 'Alexander', 'nameFirst': 'Scott'}
# Created player =  (_22613:Player {first_name: 'Scott', last_name: 'Alexander', player_id: 'alexasc01'})
# {'playerID': 'alfarjo01', 'nameLast': 'Alfaro', 'nameFirst': 'Jorge'}
# Created player =  (_22614:Player {first_name: 'Jorge', last_name: 'Alfaro', player_id: 'alfarjo01'})
# {'playerID': 'alfonel01', 'nameLast': 'Alfonzo', 'nameFirst': 'Eliezer'}
# Created player =  (_22615:Player {first_name: 'Eliezer', last_name: 'Alfonzo', player_id: 'alfonel01'})
# {'playerID': 'alforan01', 'nameLast': 'Alford', 'nameFirst': 'Anthony'}
# Created player =  (_22616:Player {first_name: 'Anthony', last_name: 'Alford', player_id: 'alforan01'})
# {'playerID': 'allenbr01', 'nameLast': 'Allen', 'nameFirst': 'Brandon'}
# Created player =  (_22617:Player {first_name: 'Brandon', last_name: 'Allen', player_id: 'allenbr01'})
# {'playerID': 'allenco01', 'nameLast': 'Allen', 'nameFirst': 'Cody'}
# Created player =  (_22618:Player {first_name: 'Cody', last_name: 'Allen', player_id: 'allenco01'})
# {'playerID': 'allengr01', 'nameLast': 'Allen', 'nameFirst': 'Greg'}
# Created player =  (_22619:Player {first_name: 'Greg', last_name: 'Allen', player_id: 'allengr01'})
# {'playerID': 'almonab01', 'nameLast': 'Almonte', 'nameFirst': 'Abraham'}
# Created player =  (_22620:Player {first_name: 'Abraham', last_name: 'Almonte', player_id: 'almonab01'})
# {'playerID': 'almoner01', 'nameLast': 'Almonte', 'nameFirst': 'Erick'}
# Created player =  (_22621:Player {first_name: 'Erick', last_name: 'Almonte', player_id: 'almoner01'})
# {'playerID': 'almonmi01', 'nameLast': 'Almonte', 'nameFirst': 'Miguel'}
# Created player =  (_22622:Player {first_name: 'Miguel', last_name: 'Almonte', player_id: 'almonmi01'})
# {'playerID': 'almonzo01', 'nameLast': 'Almonte', 'nameFirst': 'Zoilo'}
# Created player =  (_22623:Player {first_name: 'Zoilo', last_name: 'Almonte', player_id: 'almonzo01'})
# {'playerID': 'almoral01', 'nameLast': 'Almora', 'nameFirst': 'Albert'}
# Created player =  (_22624:Player {first_name: 'Albert', last_name: 'Almora', player_id: 'almoral01'})
# {'playerID': 'alonsyo01', 'nameLast': 'Alonso', 'nameFirst': 'Yonder'}
# Created player =  (_22625:Player {first_name: 'Yonder', last_name: 'Alonso', player_id: 'alonsyo01'})
# {'playerID': 'altavda01', 'nameLast': 'Altavilla', 'nameFirst': 'Dan'}
# Created player =  (_22626:Player {first_name: 'Dan', last_name: 'Altavilla', player_id: 'altavda01'})
# {'playerID': 'altheaa01', 'nameLast': 'Altherr', 'nameFirst': 'Aaron'}
# Created player =  (_22627:Player {first_name: 'Aaron', last_name: 'Altherr', player_id: 'altheaa01'})
# {'playerID': 'altuvjo01', 'nameLast': 'Altuve', 'nameFirst': 'Jose'}
# Created player =  (_22628:Player {first_name: 'Jose', last_name: 'Altuve', player_id: 'altuvjo01'})
# {'playerID': 'alvarda01', 'nameLast': 'Alvarez', 'nameFirst': 'Dario'}
# Created player =  (_22629:Player {first_name: 'Dario', last_name: 'Alvarez', player_id: 'alvarda01'})
# {'playerID': 'alvarda02', 'nameLast': 'Alvarez', 'nameFirst': 'Dariel'}
# Created player =  (_22630:Player {first_name: 'Dariel', last_name: 'Alvarez', player_id: 'alvarda02'})
# {'playerID': 'alvarhe01', 'nameLast': 'Alvarez', 'nameFirst': 'Henderson'}
# Created player =  (_22631:Player {first_name: 'Henderson', last_name: 'Alvarez', player_id: 'alvarhe01'})
# {'playerID': 'alvarjo02', 'nameLast': 'Alvarez', 'nameFirst': 'Jose'}
# Created player =  (_22632:Player {first_name: 'Jose', last_name: 'Alvarez', player_id: 'alvarjo02'})
# {'playerID': 'alvarjo03', 'nameLast': 'Alvarado', 'nameFirst': 'Jose'}
# Created player =  (_22633:Player {first_name: 'Jose', last_name: 'Alvarado', player_id: 'alvarjo03'})
# {'playerID': 'alvarpe01', 'nameLast': 'Alvarez', 'nameFirst': 'Pedro'}
# Created player =  (_22634:Player {first_name: 'Pedro', last_name: 'Alvarez', player_id: 'alvarpe01'})
# {'playerID': 'alvarrj01', 'nameLast': 'Alvarez', 'nameFirst': 'R. J.'}
# Created player =  (_22635:Player {first_name: 'R. J.', last_name: 'Alvarez', player_id: 'alvarrj01'})
# {'playerID': 'amarial01', 'nameLast': 'Amarista', 'nameFirst': 'Alexi'}
# Created player =  (_22636:Player {first_name: 'Alexi', last_name: 'Amarista', player_id: 'amarial01'})
# {'playerID': 'ambrihe01', 'nameLast': 'Ambriz', 'nameFirst': 'Hector'}
# Created player =  (_22637:Player {first_name: 'Hector', last_name: 'Ambriz', player_id: 'ambrihe01'})
# {'playerID': 'amesst01', 'nameLast': 'Ames', 'nameFirst': 'Steve'}
# Created player =  (_22638:Player {first_name: 'Steve', last_name: 'Ames', player_id: 'amesst01'})
# {'playerID': 'amezaal01', 'nameLast': 'Amezaga', 'nameFirst': 'Alfredo'}
# Created player =  (_22639:Player {first_name: 'Alfredo', last_name: 'Amezaga', player_id: 'amezaal01'})
# {'playerID': 'anderbr04', 'nameLast': 'Anderson', 'nameFirst': 'Brett'}
# Created player =  (_22640:Player {first_name: 'Brett', last_name: 'Anderson', player_id: 'anderbr04'})
# {'playerID': 'anderbr05', 'nameLast': 'Anderson', 'nameFirst': 'Bryan'}
# Created player =  (_22641:Player {first_name: 'Bryan', last_name: 'Anderson', player_id: 'anderbr05'})
# {'playerID': 'anderbr06', 'nameLast': 'Anderson', 'nameFirst': 'Brian'}
# Created player =  (_22642:Player {first_name: 'Brian', last_name: 'Anderson', player_id: 'anderbr06'})
# {'playerID': 'anderch01', 'nameLast': 'Anderson', 'nameFirst': 'Chase'}
# Created player =  (_22643:Player {first_name: 'Chase', last_name: 'Anderson', player_id: 'anderch01'})
# {'playerID': 'anderco01', 'nameLast': 'Anderson', 'nameFirst': 'Cody'}
# Created player =  (_22644:Player {first_name: 'Cody', last_name: 'Anderson', player_id: 'anderco01'})
# {'playerID': 'anderdr02', 'nameLast': 'Anderson', 'nameFirst': 'Drew'}
# Created player =  (_22645:Player {first_name: 'Drew', last_name: 'Anderson', player_id: 'anderdr02'})
# {'playerID': 'anderga01', 'nameLast': 'Anderson', 'nameFirst': 'Garret'}
# Created player =  (_22646:Player {first_name: 'Garret', last_name: 'Anderson', player_id: 'anderga01'})
# {'playerID': 'anderla03', 'nameLast': 'Anderson', 'nameFirst': 'Lars'}
# Created player =  (_22647:Player {first_name: 'Lars', last_name: 'Anderson', player_id: 'anderla03'})
# {'playerID': 'anderti01', 'nameLast': 'Anderson', 'nameFirst': 'Tim'}
# Created player =  (_22648:Player {first_name: 'Tim', last_name: 'Anderson', player_id: 'anderti01'})
# {'playerID': 'anderty01', 'nameLast': 'Anderson', 'nameFirst': 'Tyler'}
# Created player =  (_22649:Player {first_name: 'Tyler', last_name: 'Anderson', player_id: 'anderty01'})
# {'playerID': 'andinro01', 'nameLast': 'Andino', 'nameFirst': 'Robert'}
# Created player =  (_22650:Player {first_name: 'Robert', last_name: 'Andino', player_id: 'andinro01'})
# {'playerID': 'andrima01', 'nameLast': 'Andriese', 'nameFirst': 'Matt'}
# Created player =  (_22651:Player {first_name: 'Matt', last_name: 'Andriese', player_id: 'andrima01'})
# {'playerID': 'andruel01', 'nameLast': 'Andrus', 'nameFirst': 'Elvis'}
# Created player =  (_22652:Player {first_name: 'Elvis', last_name: 'Andrus', player_id: 'andruel01'})
# {'playerID': 'andujmi01', 'nameLast': 'Andujar', 'nameFirst': 'Miguel'}
# Created player =  (_22653:Player {first_name: 'Miguel', last_name: 'Andujar', player_id: 'andujmi01'})
# {'playerID': 'anglema01', 'nameLast': 'Angle', 'nameFirst': 'Matt'}
# Created player =  (_22654:Player {first_name: 'Matt', last_name: 'Angle', player_id: 'anglema01'})
# {'playerID': 'ankieri01', 'nameLast': 'Ankiel', 'nameFirst': 'Rick'}
# Created player =  (_22655:Player {first_name: 'Rick', last_name: 'Ankiel', player_id: 'ankieri01'})
# {'playerID': 'annade01', 'nameLast': 'Anna', 'nameFirst': 'Dean'}
# Created player =  (_22656:Player {first_name: 'Dean', last_name: 'Anna', player_id: 'annade01'})
# {'playerID': 'antoldu01', 'nameLast': 'Antolin', 'nameFirst': 'Dustin'}
# Created player =  (_22657:Player {first_name: 'Dustin', last_name: 'Antolin', player_id: 'antoldu01'})
# {'playerID': 'aokino01', 'nameLast': 'Aoki', 'nameFirst': 'Nori'}
# Created player =  (_22658:Player {first_name: 'Nori', last_name: 'Aoki', player_id: 'aokino01'})
# {'playerID': 'aquinja01', 'nameLast': 'Aquino', 'nameFirst': 'Jayson'}
# Created player =  (_22659:Player {first_name: 'Jayson', last_name: 'Aquino', player_id: 'aquinja01'})
# {'playerID': 'aranovi01', 'nameLast': 'Arano', 'nameFirst': 'Victor'}
# Created player =  (_22660:Player {first_name: 'Victor', last_name: 'Arano', player_id: 'aranovi01'})
# {'playerID': 'araujel01', 'nameLast': 'Araujo', 'nameFirst': 'Elvis'}
# Created player =  (_22661:Player {first_name: 'Elvis', last_name: 'Araujo', player_id: 'araujel01'})
# {'playerID': 'archech01', 'nameLast': 'Archer', 'nameFirst': 'Chris'}
# Created player =  (_22662:Player {first_name: 'Chris', last_name: 'Archer', player_id: 'archech01'})
# {'playerID': 'arciaor01', 'nameLast': 'Arcia', 'nameFirst': 'Orlando'}
# Created player =  (_22663:Player {first_name: 'Orlando', last_name: 'Arcia', player_id: 'arciaor01'})
# {'playerID': 'arciaos01', 'nameLast': 'Arcia', 'nameFirst': 'Oswaldo'}
# Created player =  (_22664:Player {first_name: 'Oswaldo', last_name: 'Arcia', player_id: 'arciaos01'})
# {'playerID': 'arenano01', 'nameLast': 'Arenado', 'nameFirst': 'Nolan'}
# Created player =  (_22665:Player {first_name: 'Nolan', last_name: 'Arenado', player_id: 'arenano01'})
# {'playerID': 'arencjp01', 'nameLast': 'Arencibia', 'nameFirst': 'J. P.'}
# Created player =  (_22666:Player {first_name: 'J. P.', last_name: 'Arencibia', player_id: 'arencjp01'})
# {'playerID': 'ariasjo01', 'nameLast': 'Arias', 'nameFirst': 'Joaquin'}
# Created player =  (_22667:Player {first_name: 'Joaquin', last_name: 'Arias', player_id: 'ariasjo01'})
# {'playerID': 'armstsh01', 'nameLast': 'Armstrong', 'nameFirst': 'Shawn'}
# Created player =  (_22668:Player {first_name: 'Shawn', last_name: 'Armstrong', player_id: 'armstsh01'})
# {'playerID': 'arojo01', 'nameLast': 'Aro', 'nameFirst': 'Jonathan'}
# Created player =  (_22669:Player {first_name: 'Jonathan', last_name: 'Aro', player_id: 'arojo01'})
# {'playerID': 'arredjo01', 'nameLast': 'Arredondo', 'nameFirst': 'Jose'}
# Created player =  (_22670:Player {first_name: 'Jose', last_name: 'Arredondo', player_id: 'arredjo01'})
# {'playerID': 'arrieja01', 'nameLast': 'Arrieta', 'nameFirst': 'Jake'}
# Created player =  (_22671:Player {first_name: 'Jake', last_name: 'Arrieta', player_id: 'arrieja01'})
# {'playerID': 'arroybr01', 'nameLast': 'Arroyo', 'nameFirst': 'Bronson'}
# Created player =  (_22672:Player {first_name: 'Bronson', last_name: 'Arroyo', player_id: 'arroybr01'})
# {'playerID': 'arroych01', 'nameLast': 'Arroyo', 'nameFirst': 'Christian'}
# Created player =  (_22673:Player {first_name: 'Christian', last_name: 'Arroyo', player_id: 'arroych01'})
# {'playerID': 'arrueer01', 'nameLast': 'Arruebarrena', 'nameFirst': 'Erisbel'}
# Created player =  (_22674:Player {first_name: 'Erisbel', last_name: 'Arruebarrena', player_id: 'arrueer01'})
# {'playerID': 'ascanjo01', 'nameLast': 'Ascanio', 'nameFirst': 'Jose'}
# Created player =  (_22675:Player {first_name: 'Jose', last_name: 'Ascanio', player_id: 'ascanjo01'})
# {'playerID': 'ascheco01', 'nameLast': 'Asche', 'nameFirst': 'Cody'}
# Created player =  (_22676:Player {first_name: 'Cody', last_name: 'Asche', player_id: 'ascheco01'})
# {'playerID': 'asheral01', 'nameLast': 'Asher', 'nameFirst': 'Alec'}
# Created player =  (_22677:Player {first_name: 'Alec', last_name: 'Asher', player_id: 'asheral01'})
# {'playerID': 'ashlene01', 'nameLast': 'Ashley', 'nameFirst': 'Nevin'}
# Created player =  (_22678:Player {first_name: 'Nevin', last_name: 'Ashley', player_id: 'ashlene01'})
# {'playerID': 'astinba01', 'nameLast': 'Astin', 'nameFirst': 'Barrett'}
# Created player =  (_22679:Player {first_name: 'Barrett', last_name: 'Astin', player_id: 'astinba01'})
# {'playerID': 'asuajca01', 'nameLast': 'Asuaje', 'nameFirst': 'Carlos'}
# Created player =  (_22680:Player {first_name: 'Carlos', last_name: 'Asuaje', player_id: 'asuajca01'})
# {'playerID': 'atchisc01', 'nameLast': 'Atchison', 'nameFirst': 'Scott'}
# Created player =  (_22681:Player {first_name: 'Scott', last_name: 'Atchison', player_id: 'atchisc01'})
# {'playerID': 'atilalu01', 'nameLast': 'Atilano', 'nameFirst': 'Luis'}
# Created player =  (_22682:Player {first_name: 'Luis', last_name: 'Atilano', player_id: 'atilalu01'})
# {'playerID': 'atkinga01', 'nameLast': 'Atkins', 'nameFirst': 'Garrett'}
# Created player =  (_22683:Player {first_name: 'Garrett', last_name: 'Atkins', player_id: 'atkinga01'})
# {'playerID': 'atkinmi01', 'nameLast': 'Atkins', 'nameFirst': 'Mitch'}
# Created player =  (_22684:Player {first_name: 'Mitch', last_name: 'Atkins', player_id: 'atkinmi01'})
# {'playerID': 'augenbr01', 'nameLast': 'Augenstein', 'nameFirst': 'Bryan'}
# Created player =  (_22685:Player {first_name: 'Bryan', last_name: 'Augenstein', player_id: 'augenbr01'})
# {'playerID': 'aumonph01', 'nameLast': 'Aumont', 'nameFirst': 'Phillippe'}
# Created player =  (_22686:Player {first_name: 'Phillippe', last_name: 'Aumont', player_id: 'aumonph01'})
# {'playerID': 'ausmubr01', 'nameLast': 'Ausmus', 'nameFirst': 'Brad'}
# Created player =  (_22687:Player {first_name: 'Brad', last_name: 'Ausmus', player_id: 'ausmubr01'})
# {'playerID': 'austity01', 'nameLast': 'Austin', 'nameFirst': 'Tyler'}
# Created player =  (_22688:Player {first_name: 'Tyler', last_name: 'Austin', player_id: 'austity01'})
# {'playerID': 'averyxa01', 'nameLast': 'Avery', 'nameFirst': 'Xavier'}
# Created player =  (_22689:Player {first_name: 'Xavier', last_name: 'Avery', player_id: 'averyxa01'})
# {'playerID': 'avilaal01', 'nameLast': 'Avila', 'nameFirst': 'Alex'}
# Created player =  (_22690:Player {first_name: 'Alex', last_name: 'Avila', player_id: 'avilaal01'})
# {'playerID': 'avilalu01', 'nameLast': 'Avilan', 'nameFirst': 'Luis'}
# Created player =  (_22691:Player {first_name: 'Luis', last_name: 'Avilan', player_id: 'avilalu01'})
# {'playerID': 'avilemi01', 'nameLast': 'Aviles', 'nameFirst': 'Mike'}
# Created player =  (_22692:Player {first_name: 'Mike', last_name: 'Aviles', player_id: 'avilemi01'})
# {'playerID': 'axelrdy01', 'nameLast': 'Axelrod', 'nameFirst': 'Dylan'}
# Created player =  (_22693:Player {first_name: 'Dylan', last_name: 'Axelrod', player_id: 'axelrdy01'})
# {'playerID': 'axforjo01', 'nameLast': 'Axford', 'nameFirst': 'John'}
# Created player =  (_22694:Player {first_name: 'John', last_name: 'Axford', player_id: 'axforjo01'})
# {'playerID': 'ayalalu01', 'nameLast': 'Ayala', 'nameFirst': 'Luis'}
# Created player =  (_22695:Player {first_name: 'Luis', last_name: 'Ayala', player_id: 'ayalalu01'})
# {'playerID': 'aybarer01', 'nameLast': 'Aybar', 'nameFirst': 'Erick'}
# Created player =  (_22696:Player {first_name: 'Erick', last_name: 'Aybar', player_id: 'aybarer01'})
# {'playerID': 'aybarwi01', 'nameLast': 'Aybar', 'nameFirst': 'Willy'}
# Created player =  (_22697:Player {first_name: 'Willy', last_name: 'Aybar', player_id: 'aybarwi01'})
# {'playerID': 'badenbu01', 'nameLast': 'Badenhop', 'nameFirst': 'Burke'}
# Created player =  (_22698:Player {first_name: 'Burke', last_name: 'Badenhop', player_id: 'badenbu01'})
# {'playerID': 'baderha01', 'nameLast': 'Bader', 'nameFirst': 'Harrison'}
# Created player =  (_22699:Player {first_name: 'Harrison', last_name: 'Bader', player_id: 'baderha01'})
# {'playerID': 'baezda01', 'nameLast': 'Baez', 'nameFirst': 'Danys'}
# Created player =  (_22700:Player {first_name: 'Danys', last_name: 'Baez', player_id: 'baezda01'})
# {'playerID': 'baezja01', 'nameLast': 'Baez', 'nameFirst': 'Javier'}
# Created player =  (_22701:Player {first_name: 'Javier', last_name: 'Baez', player_id: 'baezja01'})
# {'playerID': 'baezpe01', 'nameLast': 'Baez', 'nameFirst': 'Pedro'}
# Created player =  (_22702:Player {first_name: 'Pedro', last_name: 'Baez', player_id: 'baezpe01'})
# {'playerID': 'bailean01', 'nameLast': 'Bailey', 'nameFirst': 'Andrew'}
# Created player =  (_22703:Player {first_name: 'Andrew', last_name: 'Bailey', player_id: 'bailean01'})
# {'playerID': 'baileho02', 'nameLast': 'Bailey', 'nameFirst': 'Homer'}
# Created player =  (_22704:Player {first_name: 'Homer', last_name: 'Bailey', player_id: 'baileho02'})
# {'playerID': 'bakerje03', 'nameLast': 'Baker', 'nameFirst': 'Jeff'}
# Created player =  (_22705:Player {first_name: 'Jeff', last_name: 'Baker', player_id: 'bakerje03'})
# {'playerID': 'bakerjo01', 'nameLast': 'Baker', 'nameFirst': 'John'}
# Created player =  (_22706:Player {first_name: 'John', last_name: 'Baker', player_id: 'bakerjo01'})
# {'playerID': 'bakersc02', 'nameLast': 'Baker', 'nameFirst': 'Scott'}
# Created player =  (_22707:Player {first_name: 'Scott', last_name: 'Baker', player_id: 'bakersc02'})
# {'playerID': 'baldero01', 'nameLast': 'Baldelli', 'nameFirst': 'Rocco'}
# Created player =  (_22708:Player {first_name: 'Rocco', last_name: 'Baldelli', player_id: 'baldero01'})
# {'playerID': 'balesco01', 'nameLast': 'Balester', 'nameFirst': 'Collin'}
# Created player =  (_22709:Player {first_name: 'Collin', last_name: 'Balester', player_id: 'balesco01'})
# {'playerID': 'balfogr01', 'nameLast': 'Balfour', 'nameFirst': 'Grant'}
# Created player =  (_22710:Player {first_name: 'Grant', last_name: 'Balfour', player_id: 'balfogr01'})
# {'playerID': 'bandaan01', 'nameLast': 'Banda', 'nameFirst': 'Anthony'}
# Created player =  (_22711:Player {first_name: 'Anthony', last_name: 'Banda', player_id: 'bandaan01'})
# {'playerID': 'bandyje01', 'nameLast': 'Bandy', 'nameFirst': 'Jett'}
# Created player =  (_22712:Player {first_name: 'Jett', last_name: 'Bandy', player_id: 'bandyje01'})
# {'playerID': 'banksjo01', 'nameLast': 'Banks', 'nameFirst': 'Josh'}
# Created player =  (_22713:Player {first_name: 'Josh', last_name: 'Banks', player_id: 'banksjo01'})
# {'playerID': 'bannibr01', 'nameLast': 'Bannister', 'nameFirst': 'Brian'}
# Created player =  (_22714:Player {first_name: 'Brian', last_name: 'Bannister', player_id: 'bannibr01'})
# {'playerID': 'bantzbr01', 'nameLast': 'Bantz', 'nameFirst': 'Brandon'}
# Created player =  (_22715:Player {first_name: 'Brandon', last_name: 'Bantz', player_id: 'bantzbr01'})
# {'playerID': 'banuema01', 'nameLast': 'Banuelos', 'nameFirst': 'Manny'}
# Created player =  (_22716:Player {first_name: 'Manny', last_name: 'Banuelos', player_id: 'banuema01'})
# {'playerID': 'barajro01', 'nameLast': 'Barajas', 'nameFirst': 'Rod'}
# Created player =  (_22717:Player {first_name: 'Rod', last_name: 'Barajas', player_id: 'barajro01'})
# {'playerID': 'barbajo01', 'nameLast': 'Barbato', 'nameFirst': 'Johnny'}
# Created player =  (_22718:Player {first_name: 'Johnny', last_name: 'Barbato', player_id: 'barbajo01'})
# {'playerID': 'bardda01', 'nameLast': 'Bard', 'nameFirst': 'Daniel'}
# Created player =  (_22719:Player {first_name: 'Daniel', last_name: 'Bard', player_id: 'bardda01'})
# {'playerID': 'bardebr01', 'nameLast': 'Barden', 'nameFirst': 'Brian'}
# Created player =  (_22720:Player {first_name: 'Brian', last_name: 'Barden', player_id: 'bardebr01'})
# {'playerID': 'bardjo01', 'nameLast': 'Bard', 'nameFirst': 'Josh'}
# Created player =  (_22721:Player {first_name: 'Josh', last_name: 'Bard', player_id: 'bardjo01'})
# {'playerID': 'barmecl01', 'nameLast': 'Barmes', 'nameFirst': 'Clint'}
# Created player =  (_22722:Player {first_name: 'Clint', last_name: 'Barmes', player_id: 'barmecl01'})
# {'playerID': 'barneau01', 'nameLast': 'Barnes', 'nameFirst': 'Austin'}
# Created player =  (_22723:Player {first_name: 'Austin', last_name: 'Barnes', player_id: 'barneau01'})
# {'playerID': 'barnebr02', 'nameLast': 'Barnes', 'nameFirst': 'Brandon'}
# Created player =  (_22724:Player {first_name: 'Brandon', last_name: 'Barnes', player_id: 'barnebr02'})
# {'playerID': 'barneda01', 'nameLast': 'Barney', 'nameFirst': 'Darwin'}
# Created player =  (_22725:Player {first_name: 'Darwin', last_name: 'Barney', player_id: 'barneda01'})
# {'playerID': 'barneda02', 'nameLast': 'Barnes', 'nameFirst': 'Danny'}
# Created player =  (_22726:Player {first_name: 'Danny', last_name: 'Barnes', player_id: 'barneda02'})
# {'playerID': 'barneja01', 'nameLast': 'Barnes', 'nameFirst': 'Jacob'}
# Created player =  (_22727:Player {first_name: 'Jacob', last_name: 'Barnes', player_id: 'barneja01'})
# {'playerID': 'barnema01', 'nameLast': 'Barnes', 'nameFirst': 'Matt'}
# Created player =  (_22728:Player {first_name: 'Matt', last_name: 'Barnes', player_id: 'barnema01'})
# {'playerID': 'barnesc01', 'nameLast': 'Barnes', 'nameFirst': 'Scott'}
# Created player =  (_22729:Player {first_name: 'Scott', last_name: 'Barnes', player_id: 'barnesc01'})
# {'playerID': 'barneto01', 'nameLast': 'Barnette', 'nameFirst': 'Tony'}
# Created player =  (_22730:Player {first_name: 'Tony', last_name: 'Barnette', player_id: 'barneto01'})
# {'playerID': 'barnhtu01', 'nameLast': 'Barnhart', 'nameFirst': 'Tucker'}
# Created player =  (_22731:Player {first_name: 'Tucker', last_name: 'Barnhart', player_id: 'barnhtu01'})
# {'playerID': 'baronst01', 'nameLast': 'Baron', 'nameFirst': 'Steven'}
# Created player =  (_22732:Player {first_name: 'Steven', last_name: 'Baron', player_id: 'baronst01'})
# {'playerID': 'barraky01', 'nameLast': 'Barraclough', 'nameFirst': 'Kyle'}
# Created player =  (_22733:Player {first_name: 'Kyle', last_name: 'Barraclough', player_id: 'barraky01'})
# {'playerID': 'barreaa01', 'nameLast': 'Barrett', 'nameFirst': 'Aaron'}
# Created player =  (_22734:Player {first_name: 'Aaron', last_name: 'Barrett', player_id: 'barreaa01'})
# {'playerID': 'barrefr02', 'nameLast': 'Barreto', 'nameFirst': 'Franklin'}
# Created player =  (_22735:Player {first_name: 'Franklin', last_name: 'Barreto', player_id: 'barrefr02'})
# {'playerID': 'barreja01', 'nameLast': 'Barrett', 'nameFirst': 'Jake'}
# Created player =  (_22736:Player {first_name: 'Jake', last_name: 'Barrett', player_id: 'barreja01'})
# {'playerID': 'barriyh01', 'nameLast': 'Barrios', 'nameFirst': 'Yhonathan'}
# Created player =  (_22737:Player {first_name: 'Yhonathan', last_name: 'Barrios', player_id: 'barriyh01'})
# {'playerID': 'bartlja01', 'nameLast': 'Bartlett', 'nameFirst': 'Jason'}
# Created player =  (_22738:Player {first_name: 'Jason', last_name: 'Bartlett', player_id: 'bartlja01'})
# {'playerID': 'bartoda02', 'nameLast': 'Barton', 'nameFirst': 'Daric'}
# Created player =  (_22739:Player {first_name: 'Daric', last_name: 'Barton', player_id: 'bartoda02'})
# {'playerID': 'bassan01', 'nameLast': 'Bass', 'nameFirst': 'Anthony'}
# Created player =  (_22740:Player {first_name: 'Anthony', last_name: 'Bass', player_id: 'bassan01'})
# {'playerID': 'bassbr01', 'nameLast': 'Bass', 'nameFirst': 'Brian'}
# Created player =  (_22741:Player {first_name: 'Brian', last_name: 'Bass', player_id: 'bassbr01'})
# {'playerID': 'bassich01', 'nameLast': 'Bassitt', 'nameFirst': 'Chris'}
# Created player =  (_22742:Player {first_name: 'Chris', last_name: 'Bassitt', player_id: 'bassich01'})
# {'playerID': 'bastaan01', 'nameLast': 'Bastardo', 'nameFirst': 'Antonio'}
# Created player =  (_22743:Player {first_name: 'Antonio', last_name: 'Bastardo', player_id: 'bastaan01'})
# {'playerID': 'batismi01', 'nameLast': 'Batista', 'nameFirst': 'Miguel'}
# Created player =  (_22744:Player {first_name: 'Miguel', last_name: 'Batista', player_id: 'batismi01'})
# {'playerID': 'bauertr01', 'nameLast': 'Bauer', 'nameFirst': 'Trevor'}
# Created player =  (_22745:Player {first_name: 'Trevor', last_name: 'Bauer', player_id: 'bauertr01'})
# {'playerID': 'baumabu01', 'nameLast': 'Baumann', 'nameFirst': 'Buddy'}
# Created player =  (_22746:Player {first_name: 'Buddy', last_name: 'Baumann', player_id: 'baumabu01'})
# {'playerID': 'bautide01', 'nameLast': 'Bautista', 'nameFirst': 'Denny'}
# Created player =  (_22747:Player {first_name: 'Denny', last_name: 'Bautista', player_id: 'bautide01'})
# {'playerID': 'bautijo02', 'nameLast': 'Bautista', 'nameFirst': 'Jose'}
# Created player =  (_22748:Player {first_name: 'Jose', last_name: 'Bautista', player_id: 'bautijo02'})
# {'playerID': 'bautira01', 'nameLast': 'Bautista', 'nameFirst': 'Rafael'}
# Created player =  (_22749:Player {first_name: 'Rafael', last_name: 'Bautista', player_id: 'bautira01'})
# {'playerID': 'baxtemi01', 'nameLast': 'Baxter', 'nameFirst': 'Mike'}
# Created player =  (_22750:Player {first_name: 'Mike', last_name: 'Baxter', player_id: 'baxtemi01'})
# {'playerID': 'bayja01', 'nameLast': 'Bay', 'nameFirst': 'Jason'}
# Created player =  (_22751:Player {first_name: 'Jason', last_name: 'Bay', player_id: 'bayja01'})
# {'playerID': 'beachbr01', 'nameLast': 'Beachy', 'nameFirst': 'Brandon'}
# Created player =  (_22752:Player {first_name: 'Brandon', last_name: 'Beachy', player_id: 'beachbr01'})
# {'playerID': 'beatope01', 'nameLast': 'Beato', 'nameFirst': 'Pedro'}
# Created player =  (_22753:Player {first_name: 'Pedro', last_name: 'Beato', player_id: 'beatope01'})
# {'playerID': 'beavabl01', 'nameLast': 'Beavan', 'nameFirst': 'Blake'}
# Created player =  (_22754:Player {first_name: 'Blake', last_name: 'Beavan', player_id: 'beavabl01'})
# {'playerID': 'beckch01', 'nameLast': 'Beck', 'nameFirst': 'Chad'}
# Created player =  (_22755:Player {first_name: 'Chad', last_name: 'Beck', player_id: 'beckch01'})
# {'playerID': 'beckch02', 'nameLast': 'Beck', 'nameFirst': 'Chris'}
# Created player =  (_22756:Player {first_name: 'Chris', last_name: 'Beck', player_id: 'beckch02'})
# {'playerID': 'beckejo02', 'nameLast': 'Beckett', 'nameFirst': 'Josh'}
# Created player =  (_22757:Player {first_name: 'Josh', last_name: 'Beckett', player_id: 'beckejo02'})
# {'playerID': 'beckhgo01', 'nameLast': 'Beckham', 'nameFirst': 'Gordon'}
# Created player =  (_22758:Player {first_name: 'Gordon', last_name: 'Beckham', player_id: 'beckhgo01'})
# {'playerID': 'beckhti01', 'nameLast': 'Beckham', 'nameFirst': 'Tim'}
# Created player =  (_22759:Player {first_name: 'Tim', last_name: 'Beckham', player_id: 'beckhti01'})
# {'playerID': 'bedarer01', 'nameLast': 'Bedard', 'nameFirst': 'Erik'}
# Created player =  (_22760:Player {first_name: 'Erik', last_name: 'Bedard', player_id: 'bedarer01'})
# {'playerID': 'bedroca01', 'nameLast': 'Bedrosian', 'nameFirst': 'Cam'}
# Created player =  (_22761:Player {first_name: 'Cam', last_name: 'Bedrosian', player_id: 'bedroca01'})
# {'playerID': 'beeleda01', 'nameLast': 'Beeler', 'nameFirst': 'Dallas'}
# Created player =  (_22762:Player {first_name: 'Dallas', last_name: 'Beeler', player_id: 'beeleda01'})
# {'playerID': 'beimejo01', 'nameLast': 'Beimel', 'nameFirst': 'Joe'}
# Created player =  (_22763:Player {first_name: 'Joe', last_name: 'Beimel', player_id: 'beimejo01'})
# {'playerID': 'belfimi01', 'nameLast': 'Belfiore', 'nameFirst': 'Mike'}
# Created player =  (_22764:Player {first_name: 'Mike', last_name: 'Belfiore', player_id: 'belfimi01'})
# {'playerID': 'belisma01', 'nameLast': 'Belisle', 'nameFirst': 'Matt'}
# Created player =  (_22765:Player {first_name: 'Matt', last_name: 'Belisle', player_id: 'belisma01'})
# {'playerID': 'belisro01', 'nameLast': 'Belisario', 'nameFirst': 'Ronald'}
# Created player =  (_22766:Player {first_name: 'Ronald', last_name: 'Belisario', player_id: 'belisro01'})
# {'playerID': 'belivje01', 'nameLast': 'Beliveau', 'nameFirst': 'Jeff'}
# Created player =  (_22767:Player {first_name: 'Jeff', last_name: 'Beliveau', player_id: 'belivje01'})
# {'playerID': 'bellaan01', 'nameLast': 'Bellatti', 'nameFirst': 'Andrew'}
# Created player =  (_22768:Player {first_name: 'Andrew', last_name: 'Bellatti', player_id: 'bellaan01'})
# {'playerID': 'bellch02', 'nameLast': 'Bell', 'nameFirst': 'Chad'}
# Created player =  (_22769:Player {first_name: 'Chad', last_name: 'Bell', player_id: 'bellch02'})
# {'playerID': 'bellhe01', 'nameLast': 'Bell', 'nameFirst': 'Heath'}
# Created player =  (_22770:Player {first_name: 'Heath', last_name: 'Bell', player_id: 'bellhe01'})
# {'playerID': 'bellico01', 'nameLast': 'Bellinger', 'nameFirst': 'Cody'}
# Created player =  (_22771:Player {first_name: 'Cody', last_name: 'Bellinger', player_id: 'bellico01'})
# {'playerID': 'belliro01', 'nameLast': 'Belliard', 'nameFirst': 'Ronnie'}
# Created player =  (_22772:Player {first_name: 'Ronnie', last_name: 'Belliard', player_id: 'belliro01'})
# {'playerID': 'belljo01', 'nameLast': 'Bell', 'nameFirst': 'Josh'}
# Created player =  (_22773:Player {first_name: 'Josh', last_name: 'Bell', player_id: 'belljo01'})
# {'playerID': 'belljo02', 'nameLast': 'Bell', 'nameFirst': 'Josh'}
# Created player =  (_22774:Player {first_name: 'Josh', last_name: 'Bell', player_id: 'belljo02'})
# {'playerID': 'belltr01', 'nameLast': 'Bell', 'nameFirst': 'Trevor'}
# Created player =  (_22775:Player {first_name: 'Trevor', last_name: 'Bell', player_id: 'belltr01'})
# {'playerID': 'belnovi01', 'nameLast': 'Belnome', 'nameFirst': 'Vince'}
# Created player =  (_22776:Player {first_name: 'Vince', last_name: 'Belnome', player_id: 'belnovi01'})
# {'playerID': 'belowdu01', 'nameLast': 'Below', 'nameFirst': 'Duane'}
# Created player =  (_22777:Player {first_name: 'Duane', last_name: 'Below', player_id: 'belowdu01'})
# {'playerID': 'beltbr01', 'nameLast': 'Belt', 'nameFirst': 'Brandon'}
# Created player =  (_22778:Player {first_name: 'Brandon', last_name: 'Belt', player_id: 'beltbr01'})
# {'playerID': 'beltrad01', 'nameLast': 'Beltre', 'nameFirst': 'Adrian'}
# Created player =  (_22779:Player {first_name: 'Adrian', last_name: 'Beltre', player_id: 'beltrad01'})
# {'playerID': 'beltrca01', 'nameLast': 'Beltran', 'nameFirst': 'Carlos'}
# Created player =  (_22780:Player {first_name: 'Carlos', last_name: 'Beltran', player_id: 'beltrca01'})
# {'playerID': 'beltren01', 'nameLast': 'Beltre', 'nameFirst': 'Engel'}
# Created player =  (_22781:Player {first_name: 'Engel', last_name: 'Beltre', player_id: 'beltren01'})
# {'playerID': 'beltrom01', 'nameLast': 'Beltre', 'nameFirst': 'Omar'}
# Created player =  (_22782:Player {first_name: 'Omar', last_name: 'Beltre', player_id: 'beltrom01'})
# {'playerID': 'beninan01', 'nameLast': 'Benintendi', 'nameFirst': 'Andrew'}
# Created player =  (_22783:Player {first_name: 'Andrew', last_name: 'Benintendi', player_id: 'beninan01'})
# {'playerID': 'benoijo01', 'nameLast': 'Benoit', 'nameFirst': 'Joaquin'}
# Created player =  (_22784:Player {first_name: 'Joaquin', last_name: 'Benoit', player_id: 'benoijo01'})
# {'playerID': 'bensojo01', 'nameLast': 'Benson', 'nameFirst': 'Joe'}
# Created player =  (_22785:Player {first_name: 'Joe', last_name: 'Benson', player_id: 'bensojo01'})
# {'playerID': 'bensokr01', 'nameLast': 'Benson', 'nameFirst': 'Kris'}
# Created player =  (_22786:Player {first_name: 'Kris', last_name: 'Benson', player_id: 'bensokr01'})
# {'playerID': 'beresja01', 'nameLast': 'Beresford', 'nameFirst': 'James'}
# Created player =  (_22787:Player {first_name: 'James', last_name: 'Beresford', player_id: 'beresja01'})
# {'playerID': 'bergebr02', 'nameLast': 'Bergesen', 'nameFirst': 'Brad'}
# Created player =  (_22788:Player {first_name: 'Brad', last_name: 'Bergesen', player_id: 'bergebr02'})
# {'playerID': 'bergju01', 'nameLast': 'Berg', 'nameFirst': 'Justin'}
# Created player =  (_22789:Player {first_name: 'Justin', last_name: 'Berg', player_id: 'bergju01'})
# {'playerID': 'bergmch01', 'nameLast': 'Bergman', 'nameFirst': 'Christian'}
# Created player =  (_22790:Player {first_name: 'Christian', last_name: 'Bergman', player_id: 'bergmch01'})
# {'playerID': 'bergmja01', 'nameLast': 'Bergmann', 'nameFirst': 'Jason'}
# Created player =  (_22791:Player {first_name: 'Jason', last_name: 'Bergmann', player_id: 'bergmja01'})
# {'playerID': 'berkeja01', 'nameLast': 'Berken', 'nameFirst': 'Jason'}
# Created player =  (_22792:Player {first_name: 'Jason', last_name: 'Berken', player_id: 'berkeja01'})
# {'playerID': 'berkmla01', 'nameLast': 'Berkman', 'nameFirst': 'Lance'}
# Created player =  (_22793:Player {first_name: 'Lance', last_name: 'Berkman', player_id: 'berkmla01'})
# {'playerID': 'bernaro01', 'nameLast': 'Bernadina', 'nameFirst': 'Roger'}
# Created player =  (_22794:Player {first_name: 'Roger', last_name: 'Bernadina', player_id: 'bernaro01'})
# {'playerID': 'bernido01', 'nameLast': 'Bernier', 'nameFirst': 'Doug'}
# Created player =  (_22795:Player {first_name: 'Doug', last_name: 'Bernier', player_id: 'bernido01'})
# {'playerID': 'berrijo01', 'nameLast': 'Berrios', 'nameFirst': 'Jose'}
# Created player =  (_22796:Player {first_name: 'Jose', last_name: 'Berrios', player_id: 'berrijo01'})
# {'playerID': 'berryqu01', 'nameLast': 'Berry', 'nameFirst': 'Quintin'}
# Created player =  (_22797:Player {first_name: 'Quintin', last_name: 'Berry', player_id: 'berryqu01'})
# {'playerID': 'betande01', 'nameLast': 'Betances', 'nameFirst': 'Dellin'}
# Created player =  (_22798:Player {first_name: 'Dellin', last_name: 'Betances', player_id: 'betande01'})
# {'playerID': 'betanra01', 'nameLast': 'Betancourt', 'nameFirst': 'Rafael'}
# Created player =  (_22799:Player {first_name: 'Rafael', last_name: 'Betancourt', player_id: 'betanra01'})
# {'playerID': 'betanyu01', 'nameLast': 'Betancourt', 'nameFirst': 'Yuniesky'}
# Created player =  (_22800:Player {first_name: 'Yuniesky', last_name: 'Betancourt', player_id: 'betanyu01'})
# {'playerID': 'betemwi01', 'nameLast': 'Betemit', 'nameFirst': 'Wilson'}
# Created player =  (_22801:Player {first_name: 'Wilson', last_name: 'Betemit', player_id: 'betemwi01'})
# {'playerID': 'bethach01', 'nameLast': 'Bethancourt', 'nameFirst': 'Christian'}
# Created player =  (_22802:Player {first_name: 'Christian', last_name: 'Bethancourt', player_id: 'bethach01'})
# {'playerID': 'bettich01', 'nameLast': 'Bettis', 'nameFirst': 'Chad'}
# Created player =  (_22803:Player {first_name: 'Chad', last_name: 'Bettis', player_id: 'bettich01'})
# {'playerID': 'bettsmo01', 'nameLast': 'Betts', 'nameFirst': 'Mookie'}
# Created player =  (_22804:Player {first_name: 'Mookie', last_name: 'Betts', player_id: 'bettsmo01'})
# {'playerID': 'biagijo01', 'nameLast': 'Biagini', 'nameFirst': 'Joe'}
# Created player =  (_22805:Player {first_name: 'Joe', last_name: 'Biagini', player_id: 'biagijo01'})
# {'playerID': 'biancje01', 'nameLast': 'Bianchi', 'nameFirst': 'Jeff'}
# Created player =  (_22806:Player {first_name: 'Jeff', last_name: 'Bianchi', player_id: 'biancje01'})
# {'playerID': 'bibenau01', 'nameLast': 'Bibens-Dirkx', 'nameFirst': 'Austin'}
# Created player =  (_22807:Player {first_name: 'Austin', last_name: 'Bibens-Dirkx', player_id: 'bibenau01'})
# {'playerID': 'billibr02', 'nameLast': 'Billings', 'nameFirst': 'Bruce'}
# Created player =  (_22808:Player {first_name: 'Bruce', last_name: 'Billings', player_id: 'billibr02'})
# {'playerID': 'billich01', 'nameLast': 'Billingsley', 'nameFirst': 'Chad'}
# Created player =  (_22809:Player {first_name: 'Chad', last_name: 'Billingsley', player_id: 'billich01'})
# {'playerID': 'birdgr01', 'nameLast': 'Bird', 'nameFirst': 'Greg'}
# Created player =  (_22810:Player {first_name: 'Greg', last_name: 'Bird', player_id: 'birdgr01'})
# {'playerID': 'bisenjo01', 'nameLast': 'Bisenius', 'nameFirst': 'Joe'}
# Created player =  (_22811:Player {first_name: 'Joe', last_name: 'Bisenius', player_id: 'bisenjo01'})
# {'playerID': 'bixlebr01', 'nameLast': 'Bixler', 'nameFirst': 'Brian'}
# Created player =  (_22812:Player {first_name: 'Brian', last_name: 'Bixler', player_id: 'bixlebr01'})
# {'playerID': 'blachty01', 'nameLast': 'Blach', 'nameFirst': 'Ty'}
# Created player =  (_22813:Player {first_name: 'Ty', last_name: 'Blach', player_id: 'blachty01'})
# {'playerID': 'blackch02', 'nameLast': 'Blackmon', 'nameFirst': 'Charlie'}
# Created player =  (_22814:Player {first_name: 'Charlie', last_name: 'Blackmon', player_id: 'blackch02'})
# {'playerID': 'blackni01', 'nameLast': 'Blackburn', 'nameFirst': 'Nick'}
# Created player =  (_22815:Player {first_name: 'Nick', last_name: 'Blackburn', player_id: 'blackni01'})
# {'playerID': 'blackpa01', 'nameLast': 'Blackburn', 'nameFirst': 'Paul'}
# Created player =  (_22816:Player {first_name: 'Paul', last_name: 'Blackburn', player_id: 'blackpa01'})
# {'playerID': 'blacktr01', 'nameLast': 'Blackley', 'nameFirst': 'Travis'}
# Created player =  (_22817:Player {first_name: 'Travis', last_name: 'Blackley', player_id: 'blacktr01'})
# {'playerID': 'blackvi01', 'nameLast': 'Black', 'nameFirst': 'Vic'}
# Created player =  (_22818:Player {first_name: 'Vic', last_name: 'Black', player_id: 'blackvi01'})
# {'playerID': 'blairaa01', 'nameLast': 'Blair', 'nameFirst': 'Aaron'}
# Created player =  (_22819:Player {first_name: 'Aaron', last_name: 'Blair', player_id: 'blairaa01'})
# {'playerID': 'blairca01', 'nameLast': 'Blair', 'nameFirst': 'Carson'}
# Created player =  (_22820:Player {first_name: 'Carson', last_name: 'Blair', player_id: 'blairca01'})
# {'playerID': 'blakeca01', 'nameLast': 'Blake', 'nameFirst': 'Casey'}
# Created player =  (_22821:Player {first_name: 'Casey', last_name: 'Blake', player_id: 'blakeca01'})
# {'playerID': 'blaloha01', 'nameLast': 'Blalock', 'nameFirst': 'Hank'}
# Created player =  (_22822:Player {first_name: 'Hank', last_name: 'Blalock', player_id: 'blaloha01'})
# {'playerID': 'blancan01', 'nameLast': 'Blanco', 'nameFirst': 'Andres'}
# Created player =  (_22823:Player {first_name: 'Andres', last_name: 'Blanco', player_id: 'blancan01'})
# {'playerID': 'blancgr01', 'nameLast': 'Blanco', 'nameFirst': 'Gregor'}
# Created player =  (_22824:Player {first_name: 'Gregor', last_name: 'Blanco', player_id: 'blancgr01'})
# {'playerID': 'blanche01', 'nameLast': 'Blanco', 'nameFirst': 'Henry'}
# Created player =  (_22825:Player {first_name: 'Henry', last_name: 'Blanco', player_id: 'blanche01'})
# {'playerID': 'blankky01', 'nameLast': 'Blanks', 'nameFirst': 'Kyle'}
# Created player =  (_22826:Player {first_name: 'Kyle', last_name: 'Blanks', player_id: 'blankky01'})
# {'playerID': 'blantjo01', 'nameLast': 'Blanton', 'nameFirst': 'Joe'}
# Created player =  (_22827:Player {first_name: 'Joe', last_name: 'Blanton', player_id: 'blantjo01'})
# {'playerID': 'blashja01', 'nameLast': 'Blash', 'nameFirst': 'Jabari'}
# Created player =  (_22828:Player {first_name: 'Jabari', last_name: 'Blash', player_id: 'blashja01'})
# {'playerID': 'blazemi01', 'nameLast': 'Blazek', 'nameFirst': 'Michael'}
# Created player =  (_22829:Player {first_name: 'Michael', last_name: 'Blazek', player_id: 'blazemi01'})
# {'playerID': 'bleieri01', 'nameLast': 'Bleier', 'nameFirst': 'Richard'}
# Created player =  (_22830:Player {first_name: 'Richard', last_name: 'Bleier', player_id: 'bleieri01'})
# {'playerID': 'blevije01', 'nameLast': 'Blevins', 'nameFirst': 'Jerry'}
# Created player =  (_22831:Player {first_name: 'Jerry', last_name: 'Blevins', player_id: 'blevije01'})
# {'playerID': 'bloomwi01', 'nameLast': 'Bloomquist', 'nameFirst': 'Willie'}
# Created player =  (_22832:Player {first_name: 'Willie', last_name: 'Bloomquist', player_id: 'bloomwi01'})
# {'playerID': 'blumge01', 'nameLast': 'Blum', 'nameFirst': 'Geoff'}
# Created player =  (_22833:Player {first_name: 'Geoff', last_name: 'Blum', player_id: 'blumge01'})
# {'playerID': 'bochybr02', 'nameLast': 'Bochy', 'nameFirst': 'Brett'}
# Created player =  (_22834:Player {first_name: 'Brett', last_name: 'Bochy', player_id: 'bochybr02'})
# {'playerID': 'bococbr01', 'nameLast': 'Bocock', 'nameFirst': 'Brian'}
# Created player =  (_22835:Player {first_name: 'Brian', last_name: 'Bocock', player_id: 'bococbr01'})
# {'playerID': 'boescbr01', 'nameLast': 'Boesch', 'nameFirst': 'Brennan'}
# Created player =  (_22836:Player {first_name: 'Brennan', last_name: 'Boesch', player_id: 'boescbr01'})
# {'playerID': 'bogaexa01', 'nameLast': 'Bogaerts', 'nameFirst': 'Xander'}
# Created player =  (_22837:Player {first_name: 'Xander', last_name: 'Bogaerts', player_id: 'bogaexa01'})
# {'playerID': 'boggsbr01', 'nameLast': 'Boggs', 'nameFirst': 'Brandon'}
# Created player =  (_22838:Player {first_name: 'Brandon', last_name: 'Boggs', player_id: 'boggsbr01'})
# {'playerID': 'boggsmi01', 'nameLast': 'Boggs', 'nameFirst': 'Mitchell'}
# Created player =  (_22839:Player {first_name: 'Mitchell', last_name: 'Boggs', player_id: 'boggsmi01'})
# {'playerID': 'bogusbr01', 'nameLast': 'Bogusevic', 'nameFirst': 'Brian'}
# Created player =  (_22840:Player {first_name: 'Brian', last_name: 'Bogusevic', player_id: 'bogusbr01'})
# {'playerID': 'bolsimi01', 'nameLast': 'Bolsinger', 'nameFirst': 'Mike'}
# Created player =  (_22841:Player {first_name: 'Mike', last_name: 'Bolsinger', player_id: 'bolsimi01'})
# {'playerID': 'bondeje01', 'nameLast': 'Bonderman', 'nameFirst': 'Jeremy'}
# Created player =  (_22842:Player {first_name: 'Jeremy', last_name: 'Bonderman', player_id: 'bondeje01'})
# {'playerID': 'bonifem01', 'nameLast': 'Bonifacio', 'nameFirst': 'Emilio'}
# Created player =  (_22843:Player {first_name: 'Emilio', last_name: 'Bonifacio', player_id: 'bonifem01'})
# {'playerID': 'bonifjo01', 'nameLast': 'Bonifacio', 'nameFirst': 'Jorge'}
# Created player =  (_22844:Player {first_name: 'Jorge', last_name: 'Bonifacio', player_id: 'bonifjo01'})
# {'playerID': 'bonilli01', 'nameLast': 'Bonilla', 'nameFirst': 'Lisalverto'}
# Created player =  (_22845:Player {first_name: 'Lisalverto', last_name: 'Bonilla', player_id: 'bonilli01'})
# {'playerID': 'bonined01', 'nameLast': 'Bonine', 'nameFirst': 'Eddie'}
# Created player =  (_22846:Player {first_name: 'Eddie', last_name: 'Bonine', player_id: 'bonined01'})
# {'playerID': 'bonsebo01', 'nameLast': 'Bonser', 'nameFirst': 'Boof'}
# Created player =  (_22847:Player {first_name: 'Boof', last_name: 'Bonser', player_id: 'bonsebo01'})
# {'playerID': 'bootcch01', 'nameLast': 'Bootcheck', 'nameFirst': 'Chris'}
# Created player =  (_22848:Player {first_name: 'Chris', last_name: 'Bootcheck', player_id: 'bootcch01'})
# {'playerID': 'borboju01', 'nameLast': 'Borbon', 'nameFirst': 'Julio'}
# Created player =  (_22849:Player {first_name: 'Julio', last_name: 'Borbon', player_id: 'borboju01'})
# {'playerID': 'bormajo01', 'nameLast': 'Bormann', 'nameFirst': 'John'}
# Created player =  (_22850:Player {first_name: 'John', last_name: 'Bormann', player_id: 'bormajo01'})
# {'playerID': 'boscajc01', 'nameLast': 'Boscan', 'nameFirst': 'J. C.'}
# Created player =  (_22851:Player {first_name: 'J. C.', last_name: 'Boscan', player_id: 'boscajc01'})
# {'playerID': 'boscawi01', 'nameLast': 'Boscan', 'nameFirst': 'Wilfredo'}
# Created player =  (_22852:Player {first_name: 'Wilfredo', last_name: 'Boscan', player_id: 'boscawi01'})
# {'playerID': 'boshebu01', 'nameLast': 'Boshers', 'nameFirst': 'Buddy'}
# Created player =  (_22853:Player {first_name: 'Buddy', last_name: 'Boshers', player_id: 'boshebu01'})
# ...
# {'playerID': 'whitlch01', 'nameLast': 'Whitley', 'nameFirst': 'Chase'}
# Created player =  (_25540:Player {first_name: 'Chase', last_name: 'Whitley', player_id: 'whitlch01'})
# {'playerID': 'wielajo01', 'nameLast': 'Wieland', 'nameFirst': 'Joe'}
# Created player =  (_25541:Player {first_name: 'Joe', last_name: 'Wieland', player_id: 'wielajo01'})
# {'playerID': 'wietema01', 'nameLast': 'Wieters', 'nameFirst': 'Matt'}
# Created player =  (_25542:Player {first_name: 'Matt', last_name: 'Wieters', player_id: 'wietema01'})
# {'playerID': 'wiggity01', 'nameLast': 'Wigginton', 'nameFirst': 'Ty'}
# Created player =  (_25543:Player {first_name: 'Ty', last_name: 'Wigginton', player_id: 'wiggity01'})
# {'playerID': 'wilheto01', 'nameLast': 'Wilhelmsen', 'nameFirst': 'Tom'}
# Created player =  (_25544:Player {first_name: 'Tom', last_name: 'Wilhelmsen', player_id: 'wilheto01'})
# {'playerID': 'wilkad01', 'nameLast': 'Wilk', 'nameFirst': 'Adam'}
# Created player =  (_25545:Player {first_name: 'Adam', last_name: 'Wilk', player_id: 'wilkad01'})
# {'playerID': 'wilkeaa01', 'nameLast': 'Wilkerson', 'nameFirst': 'Aaron'}
# Created player =  (_25546:Player {first_name: 'Aaron', last_name: 'Wilkerson', player_id: 'wilkeaa01'})
# {'playerID': 'wilkian01', 'nameLast': 'Wilkins', 'nameFirst': 'Andy'}
# Created player =  (_25547:Player {first_name: 'Andy', last_name: 'Wilkins', player_id: 'wilkian01'})
# {'playerID': 'willido03', 'nameLast': 'Willis', 'nameFirst': 'Dontrelle'}
# Created player =  (_25548:Player {first_name: 'Dontrelle', last_name: 'Willis', player_id: 'willido03'})
# {'playerID': 'willija01', 'nameLast': 'Williams', 'nameFirst': 'Jackson'}
# Created player =  (_25549:Player {first_name: 'Jackson', last_name: 'Williams', player_id: 'willija01'})
# {'playerID': 'willije02', 'nameLast': 'Williams', 'nameFirst': 'Jerome'}
# Created player =  (_25550:Player {first_name: 'Jerome', last_name: 'Williams', player_id: 'willije02'})
# {'playerID': 'willijo03', 'nameLast': 'Willingham', 'nameFirst': 'Josh'}
# Created player =  (_25551:Player {first_name: 'Josh', last_name: 'Willingham', player_id: 'willijo03'})
# {'playerID': 'willima07', 'nameLast': 'Williams', 'nameFirst': 'Mason'}
# Created player =  (_25552:Player {first_name: 'Mason', last_name: 'Williams', player_id: 'willima07'})
# {'playerID': 'willima08', 'nameLast': 'Williamson', 'nameFirst': 'Mac'}
# Created player =  (_25553:Player {first_name: 'Mac', last_name: 'Williamson', player_id: 'willima08'})
# {'playerID': 'willini01', 'nameLast': 'Williams', 'nameFirst': 'Nick'}
# Created player =  (_25554:Player {first_name: 'Nick', last_name: 'Williams', player_id: 'willini01'})
# {'playerID': 'willira01', 'nameLast': 'Williams', 'nameFirst': 'Randy'}
# Created player =  (_25555:Player {first_name: 'Randy', last_name: 'Williams', player_id: 'willira01'})
# {'playerID': 'willire03', 'nameLast': 'Willits', 'nameFirst': 'Reggie'}
# Created player =  (_25556:Player {first_name: 'Reggie', last_name: 'Willits', player_id: 'willire03'})
# {'playerID': 'willita01', 'nameLast': 'Williams', 'nameFirst': 'Taylor'}
# Created player =  (_25557:Player {first_name: 'Taylor', last_name: 'Williams', player_id: 'willita01'})
# {'playerID': 'willitr01', 'nameLast': 'Williams', 'nameFirst': 'Trevor'}
# Created player =  (_25558:Player {first_name: 'Trevor', last_name: 'Williams', player_id: 'willitr01'})
# {'playerID': 'wilsoal01', 'nameLast': 'Wilson', 'nameFirst': 'Alex'}
# Created player =  (_25559:Player {first_name: 'Alex', last_name: 'Wilson', player_id: 'wilsoal01'})
# {'playerID': 'wilsobo02', 'nameLast': 'Wilson', 'nameFirst': 'Bobby'}
# Created player =  (_25560:Player {first_name: 'Bobby', last_name: 'Wilson', player_id: 'wilsobo02'})
# {'playerID': 'wilsobr01', 'nameLast': 'Wilson', 'nameFirst': 'Brian'}
# Created player =  (_25561:Player {first_name: 'Brian', last_name: 'Wilson', player_id: 'wilsobr01'})
# {'playerID': 'wilsocj01', 'nameLast': 'Wilson', 'nameFirst': 'C. J.'}
# Created player =  (_25562:Player {first_name: 'C. J.', last_name: 'Wilson', player_id: 'wilsocj01'})
# {'playerID': 'wilsoja02', 'nameLast': 'Wilson', 'nameFirst': 'Jack'}
# Created player =  (_25563:Player {first_name: 'Jack', last_name: 'Wilson', player_id: 'wilsoja02'})
# {'playerID': 'wilsojo03', 'nameLast': 'Wilson', 'nameFirst': 'Josh'}
# Created player =  (_25564:Player {first_name: 'Josh', last_name: 'Wilson', player_id: 'wilsojo03'})
# {'playerID': 'wilsoju10', 'nameLast': 'Wilson', 'nameFirst': 'Justin'}
# Created player =  (_25565:Player {first_name: 'Justin', last_name: 'Wilson', player_id: 'wilsoju10'})
# {'playerID': 'wilsomi02', 'nameLast': 'Wilson', 'nameFirst': 'Mike'}
# Created player =  (_25566:Player {first_name: 'Mike', last_name: 'Wilson', player_id: 'wilsomi02'})
# {'playerID': 'wilsoty01', 'nameLast': 'Wilson', 'nameFirst': 'Tyler'}
# Created player =  (_25567:Player {first_name: 'Tyler', last_name: 'Wilson', player_id: 'wilsoty01'})
# {'playerID': 'wimmeal01', 'nameLast': 'Wimmers', 'nameFirst': 'Alex'}
# Created player =  (_25568:Player {first_name: 'Alex', last_name: 'Wimmers', player_id: 'wimmeal01'})
# {'playerID': 'winkeje01', 'nameLast': 'Winker', 'nameFirst': 'Jesse'}
# Created player =  (_25569:Player {first_name: 'Jesse', last_name: 'Winker', player_id: 'winkeje01'})
# {'playerID': 'winklda01', 'nameLast': 'Winkler', 'nameFirst': 'Dan'}
# Created player =  (_25570:Player {first_name: 'Dan', last_name: 'Winkler', player_id: 'winklda01'})
# {'playerID': 'winnra01', 'nameLast': 'Winn', 'nameFirst': 'Randy'}
# Created player =  (_25571:Player {first_name: 'Randy', last_name: 'Winn', player_id: 'winnra01'})
# {'playerID': 'wisede01', 'nameLast': 'Wise', 'nameFirst': 'Dewayne'}
# Created player =  (_25572:Player {first_name: 'Dewayne', last_name: 'Wise', player_id: 'wisede01'})
# {'playerID': 'wislema01', 'nameLast': 'Wisler', 'nameFirst': 'Matt'}
# Created player =  (_25573:Player {first_name: 'Matt', last_name: 'Wisler', player_id: 'wislema01'})
# {'playerID': 'withrch01', 'nameLast': 'Withrow', 'nameFirst': 'Chris'}
# Created player =  (_25574:Player {first_name: 'Chris', last_name: 'Withrow', player_id: 'withrch01'})
# {'playerID': 'wittgni01', 'nameLast': 'Wittgren', 'nameFirst': 'Nick'}
# Created player =  (_25575:Player {first_name: 'Nick', last_name: 'Wittgren', player_id: 'wittgni01'})
# {'playerID': 'wojcias01', 'nameLast': 'Wojciechowski', 'nameFirst': 'Asher'}
# Created player =  (_25576:Player {first_name: 'Asher', last_name: 'Wojciechowski', player_id: 'wojcias01'})
# {'playerID': 'wolfra02', 'nameLast': 'Wolf', 'nameFirst': 'Randy'}
# Created player =  (_25577:Player {first_name: 'Randy', last_name: 'Wolf', player_id: 'wolfra02'})
# {'playerID': 'wolfro01', 'nameLast': 'Wolf', 'nameFirst': 'Ross'}
# Created player =  (_25578:Player {first_name: 'Ross', last_name: 'Wolf', player_id: 'wolfro01'})
# {'playerID': 'wolteto01', 'nameLast': 'Wolters', 'nameFirst': 'Tony'}
# Created player =  (_25579:Player {first_name: 'Tony', last_name: 'Wolters', player_id: 'wolteto01'})
# {'playerID': 'wongko01', 'nameLast': 'Wong', 'nameFirst': 'Kolten'}
# Created player =  (_25580:Player {first_name: 'Kolten', last_name: 'Wong', player_id: 'wongko01'})
# {'playerID': 'woodal02', 'nameLast': 'Wood', 'nameFirst': 'Alex'}
# Created player =  (_25581:Player {first_name: 'Alex', last_name: 'Wood', player_id: 'woodal02'})
# {'playerID': 'woodbl01', 'nameLast': 'Wood', 'nameFirst': 'Blake'}
# Created player =  (_25582:Player {first_name: 'Blake', last_name: 'Wood', player_id: 'woodbl01'})
# {'playerID': 'woodbr01', 'nameLast': 'Wood', 'nameFirst': 'Brandon'}
# Created player =  (_25583:Player {first_name: 'Brandon', last_name: 'Wood', player_id: 'woodbr01'})
# {'playerID': 'woodhu01', 'nameLast': 'Wood', 'nameFirst': 'Hunter'}
# Created player =  (_25584:Player {first_name: 'Hunter', last_name: 'Wood', player_id: 'woodhu01'})
# {'playerID': 'woodke02', 'nameLast': 'Wood', 'nameFirst': 'Kerry'}
# Created player =  (_25585:Player {first_name: 'Kerry', last_name: 'Wood', player_id: 'woodke02'})
# {'playerID': 'woodrbr01', 'nameLast': 'Woodruff', 'nameFirst': 'Brandon'}
# Created player =  (_25586:Player {first_name: 'Brandon', last_name: 'Woodruff', player_id: 'woodrbr01'})
# {'playerID': 'woodti01', 'nameLast': 'Wood', 'nameFirst': 'Tim'}
# Created player =  (_25587:Player {first_name: 'Tim', last_name: 'Wood', player_id: 'woodti01'})
# {'playerID': 'woodtr01', 'nameLast': 'Wood', 'nameFirst': 'Travis'}
# Created player =  (_25588:Player {first_name: 'Travis', last_name: 'Wood', player_id: 'woodtr01'})
# {'playerID': 'woodwch01', 'nameLast': 'Woodward', 'nameFirst': 'Chris'}
# Created player =  (_25589:Player {first_name: 'Chris', last_name: 'Woodward', player_id: 'woodwch01'})
# {'playerID': 'wootero01', 'nameLast': 'Wooten', 'nameFirst': 'Rob'}
# Created player =  (_25590:Player {first_name: 'Rob', last_name: 'Wooten', player_id: 'wootero01'})
# {'playerID': 'workmbr01', 'nameLast': 'Workman', 'nameFirst': 'Brandon'}
# Created player =  (_25591:Player {first_name: 'Brandon', last_name: 'Workman', player_id: 'workmbr01'})
# {'playerID': 'worleva01', 'nameLast': 'Worley', 'nameFirst': 'Vance'}
# Created player =  (_25592:Player {first_name: 'Vance', last_name: 'Worley', player_id: 'worleva01'})
# {'playerID': 'worrema01', 'nameLast': 'Worrell', 'nameFirst': 'Mark'}
# Created player =  (_25593:Player {first_name: 'Mark', last_name: 'Worrell', player_id: 'worrema01'})
# {'playerID': 'worthda01', 'nameLast': 'Worth', 'nameFirst': 'Danny'}
# Created player =  (_25594:Player {first_name: 'Danny', last_name: 'Worth', player_id: 'worthda01'})
# {'playerID': 'wrighda03', 'nameLast': 'Wright', 'nameFirst': 'David'}
# Created player =  (_25595:Player {first_name: 'David', last_name: 'Wright', player_id: 'wrighda03'})
# {'playerID': 'wrighda04', 'nameLast': 'Wright', 'nameFirst': 'Daniel'}
# Created player =  (_25596:Player {first_name: 'Daniel', last_name: 'Wright', player_id: 'wrighda04'})
# {'playerID': 'wrighja01', 'nameLast': 'Wright', 'nameFirst': 'Jamey'}
# Created player =  (_25597:Player {first_name: 'Jamey', last_name: 'Wright', player_id: 'wrighja01'})
# {'playerID': 'wrighmi01', 'nameLast': 'Wright', 'nameFirst': 'Mike'}
# Created player =  (_25598:Player {first_name: 'Mike', last_name: 'Wright', player_id: 'wrighmi01'})
# {'playerID': 'wrighst01', 'nameLast': 'Wright', 'nameFirst': 'Steven'}
# Created player =  (_25599:Player {first_name: 'Steven', last_name: 'Wright', player_id: 'wrighst01'})
# {'playerID': 'wrighwe01', 'nameLast': 'Wright', 'nameFirst': 'Wesley'}
# Created player =  (_25600:Player {first_name: 'Wesley', last_name: 'Wright', player_id: 'wrighwe01'})
# {'playerID': 'wuertmi01', 'nameLast': 'Wuertz', 'nameFirst': 'Michael'}
# Created player =  (_25601:Player {first_name: 'Michael', last_name: 'Wuertz', player_id: 'wuertmi01'})
# {'playerID': 'yacabji01', 'nameLast': 'Yacabonis', 'nameFirst': 'Jimmy'}
# Created player =  (_25602:Player {first_name: 'Jimmy', last_name: 'Yacabonis', player_id: 'yacabji01'})
# {'playerID': 'yateski01', 'nameLast': 'Yates', 'nameFirst': 'Kirby'}
# Created player =  (_25603:Player {first_name: 'Kirby', last_name: 'Yates', player_id: 'yateski01'})
# {'playerID': 'yelicch01', 'nameLast': 'Yelich', 'nameFirst': 'Christian'}
# Created player =  (_25604:Player {first_name: 'Christian', last_name: 'Yelich', player_id: 'yelicch01'})
# {'playerID': 'ynoaga01', 'nameLast': 'Ynoa', 'nameFirst': 'Gabriel'}
# Created player =  (_25605:Player {first_name: 'Gabriel', last_name: 'Ynoa', player_id: 'ynoaga01'})
# {'playerID': 'ynoami01', 'nameLast': 'Ynoa', 'nameFirst': 'Michael'}
# Created player =  (_25606:Player {first_name: 'Michael', last_name: 'Ynoa', player_id: 'ynoami01'})
# {'playerID': 'ynoara01', 'nameLast': 'Ynoa', 'nameFirst': 'Rafael'}
# Created player =  (_25607:Player {first_name: 'Rafael', last_name: 'Ynoa', player_id: 'ynoara01'})
# {'playerID': 'youklke01', 'nameLast': 'Youkilis', 'nameFirst': 'Kevin'}
# Created player =  (_25608:Player {first_name: 'Kevin', last_name: 'Youkilis', player_id: 'youklke01'})
# {'playerID': 'youngch03', 'nameLast': 'Young', 'nameFirst': 'Chris'}
# Created player =  (_25609:Player {first_name: 'Chris', last_name: 'Young', player_id: 'youngch03'})
# {'playerID': 'youngch04', 'nameLast': 'Young', 'nameFirst': 'Chris'}
# Created player =  (_25610:Player {first_name: 'Chris', last_name: 'Young', player_id: 'youngch04'})
# {'playerID': 'youngde03', 'nameLast': 'Young', 'nameFirst': 'Delmon'}
# Created player =  (_25611:Player {first_name: 'Delmon', last_name: 'Young', player_id: 'youngde03'})
# {'playerID': 'youngde04', 'nameLast': 'Young', 'nameFirst': 'Delwyn'}
# Created player =  (_25612:Player {first_name: 'Delwyn', last_name: 'Young', player_id: 'youngde04'})
# {'playerID': 'younger03', 'nameLast': 'Young', 'nameFirst': 'Eric'}
# Created player =  (_25613:Player {first_name: 'Eric', last_name: 'Young', player_id: 'younger03'})
# {'playerID': 'youngma02', 'nameLast': 'Young', 'nameFirst': 'Matt'}
# Created player =  (_25614:Player {first_name: 'Matt', last_name: 'Young', player_id: 'youngma02'})
# {'playerID': 'youngma03', 'nameLast': 'Younginer', 'nameFirst': 'Madison'}
# Created player =  (_25615:Player {first_name: 'Madison', last_name: 'Younginer', player_id: 'youngma03'})
# {'playerID': 'youngmi02', 'nameLast': 'Young', 'nameFirst': 'Michael'}
# Created player =  (_25616:Player {first_name: 'Michael', last_name: 'Young', player_id: 'youngmi02'})
# {'playerID': 'zagunma01', 'nameLast': 'Zagunis', 'nameFirst': 'Mark'}
# Created player =  (_25617:Player {first_name: 'Mark', last_name: 'Zagunis', player_id: 'zagunma01'})
# {'playerID': 'zagurmi01', 'nameLast': 'Zagurski', 'nameFirst': 'Mike'}
# Created player =  (_25618:Player {first_name: 'Mike', last_name: 'Zagurski', player_id: 'zagurmi01'})
# {'playerID': 'zambrca01', 'nameLast': 'Zambrano', 'nameFirst': 'Carlos'}
# Created player =  (_25619:Player {first_name: 'Carlos', last_name: 'Zambrano', player_id: 'zambrca01'})
# {'playerID': 'zastrro01', 'nameLast': 'Zastryzny', 'nameFirst': 'Rob'}
# Created player =  (_25620:Player {first_name: 'Rob', last_name: 'Zastryzny', player_id: 'zastrro01'})
# {'playerID': 'zaungr01', 'nameLast': 'Zaun', 'nameFirst': 'Gregg'}
# Created player =  (_25621:Player {first_name: 'Gregg', last_name: 'Zaun', player_id: 'zaungr01'})
# {'playerID': 'zawadla01', 'nameLast': 'Zawadzki', 'nameFirst': 'Lance'}
# Created player =  (_25622:Player {first_name: 'Lance', last_name: 'Zawadzki', player_id: 'zawadla01'})
# {'playerID': 'zeidjo01', 'nameLast': 'Zeid', 'nameFirst': 'Josh'}
# Created player =  (_25623:Player {first_name: 'Josh', last_name: 'Zeid', player_id: 'zeidjo01'})
# {'playerID': 'zieglbr01', 'nameLast': 'Ziegler', 'nameFirst': 'Brad'}
# Created player =  (_25624:Player {first_name: 'Brad', last_name: 'Ziegler', player_id: 'zieglbr01'})
# {'playerID': 'zimmebr01', 'nameLast': 'Zimmer', 'nameFirst': 'Bradley'}
# Created player =  (_25625:Player {first_name: 'Bradley', last_name: 'Zimmer', player_id: 'zimmebr01'})
# {'playerID': 'zimmejo02', 'nameLast': 'Zimmermann', 'nameFirst': 'Jordan'}
# Created player =  (_25626:Player {first_name: 'Jordan', last_name: 'Zimmermann', player_id: 'zimmejo02'})
# {'playerID': 'zimmery01', 'nameLast': 'Zimmerman', 'nameFirst': 'Ryan'}
# Created player =  (_25627:Player {first_name: 'Ryan', last_name: 'Zimmerman', player_id: 'zimmery01'})
# {'playerID': 'zitoba01', 'nameLast': 'Zito', 'nameFirst': 'Barry'}
# Created player =  (_25628:Player {first_name: 'Barry', last_name: 'Zito', player_id: 'zitoba01'})
# {'playerID': 'zobribe01', 'nameLast': 'Zobrist', 'nameFirst': 'Ben'}
# Created player =  (_25629:Player {first_name: 'Ben', last_name: 'Zobrist', player_id: 'zobribe01'})
# {'playerID': 'zumayjo01', 'nameLast': 'Zumaya', 'nameFirst': 'Joel'}
# Created player =  (_25630:Player {first_name: 'Joel', last_name: 'Zumaya', player_id: 'zumayjo01'})
# {'playerID': 'zuninmi01', 'nameLast': 'Zunino', 'nameFirst': 'Mike'}
# Created player =  (_25631:Player {first_name: 'Mike', last_name: 'Zunino', player_id: 'zuninmi01'})
# {'playerID': 'zychto01', 'nameLast': 'Zych', 'nameFirst': 'Tony'}
# Created player =  (_25632:Player {first_name: 'Tony', last_name: 'Zych', player_id: 'zychto01'})
# Loaded  3057 records.

# %% [markdown]
# - Test that we loaded a player.

# %%
raise NotImplementedError("Do not run this code fool!")

p = fg.get_player('ortizda01')
if p is not None:
    print(p)
else:
    print("Not found.")
    
p = fg.get_player('willite01')
if p is not None:
    print(p)
else:
    print("Not found.")
# Out:
# (_24601:Player {first_name: 'David', last_name: 'Ortiz', player_id: 'ortizda01'})
# Not found.

# %% [markdown]
# - The following is the same basic logic for teams.

# %%
raise NotImplementedError("Do not run this code fool!")

def load_teams():

    q = "SELECT distinct teamid, name from teams where yearid >= 2000"

    curs = cnx.cursor()
    curs.execute(q)

    
    cnt = 0
    r = curs.fetchone()
    while r is not None:

        print(r)
        cnt += 1

        if r is not None:
            p = fg.create_team(team_id=r['teamid'], team_name=r['name'])
            print("Created team = ", p)
            
        r = curs.fetchone()

    print("Loaded ", cnt, "records.")

# %%
raise NotImplementedError("Do not run this code fool!")

load_teams()
# Out:
# {'teamid': 'ANA', 'name': 'Anaheim Angels'}
# Created team =  (_71697:Team {team_id: 'ANA', team_name: 'Anaheim Angels'})
# {'teamid': 'ARI', 'name': 'Arizona Diamondbacks'}
# Created team =  (_71698:Team {team_id: 'ARI', team_name: 'Arizona Diamondbacks'})
# {'teamid': 'ATL', 'name': 'Atlanta Braves'}
# Created team =  (_71699:Team {team_id: 'ATL', team_name: 'Atlanta Braves'})
# {'teamid': 'BAL', 'name': 'Baltimore Orioles'}
# Created team =  (_71700:Team {team_id: 'BAL', team_name: 'Baltimore Orioles'})
# {'teamid': 'BOS', 'name': 'Boston Red Sox'}
# Created team =  (_71701:Team {team_id: 'BOS', team_name: 'Boston Red Sox'})
# {'teamid': 'CHA', 'name': 'Chicago White Sox'}
# Created team =  (_71702:Team {team_id: 'CHA', team_name: 'Chicago White Sox'})
# {'teamid': 'CHN', 'name': 'Chicago Cubs'}
# Created team =  (_71703:Team {team_id: 'CHN', team_name: 'Chicago Cubs'})
# {'teamid': 'CIN', 'name': 'Cincinnati Reds'}
# Created team =  (_71704:Team {team_id: 'CIN', team_name: 'Cincinnati Reds'})
# {'teamid': 'CLE', 'name': 'Cleveland Indians'}
# Created team =  (_71705:Team {team_id: 'CLE', team_name: 'Cleveland Indians'})
# {'teamid': 'COL', 'name': 'Colorado Rockies'}
# Created team =  (_71706:Team {team_id: 'COL', team_name: 'Colorado Rockies'})
# {'teamid': 'DET', 'name': 'Detroit Tigers'}
# Created team =  (_71707:Team {team_id: 'DET', team_name: 'Detroit Tigers'})
# {'teamid': 'FLO', 'name': 'Florida Marlins'}
# Created team =  (_71708:Team {team_id: 'FLO', team_name: 'Florida Marlins'})
# {'teamid': 'HOU', 'name': 'Houston Astros'}
# Created team =  (_71709:Team {team_id: 'HOU', team_name: 'Houston Astros'})
# {'teamid': 'KCA', 'name': 'Kansas City Royals'}
# Created team =  (_71710:Team {team_id: 'KCA', team_name: 'Kansas City Royals'})
# {'teamid': 'LAA', 'name': 'Los Angeles Angels of Anaheim'}
# Created team =  (_71711:Team {team_id: 'LAA', team_name: 'Los Angeles Angels of Anaheim'})
# {'teamid': 'LAN', 'name': 'Los Angeles Dodgers'}
# Created team =  (_71712:Team {team_id: 'LAN', team_name: 'Los Angeles Dodgers'})
# {'teamid': 'MIA', 'name': 'Miami Marlins'}
# Created team =  (_71713:Team {team_id: 'MIA', team_name: 'Miami Marlins'})
# {'teamid': 'MIL', 'name': 'Milwaukee Brewers'}
# Created team =  (_71714:Team {team_id: 'MIL', team_name: 'Milwaukee Brewers'})
# {'teamid': 'MIN', 'name': 'Minnesota Twins'}
# Created team =  (_71715:Team {team_id: 'MIN', team_name: 'Minnesota Twins'})
# {'teamid': 'MON', 'name': 'Montreal Expos'}
# Created team =  (_71716:Team {team_id: 'MON', team_name: 'Montreal Expos'})
# {'teamid': 'NYA', 'name': 'New York Yankees'}
# Created team =  (_71717:Team {team_id: 'NYA', team_name: 'New York Yankees'})
# {'teamid': 'NYN', 'name': 'New York Mets'}
# Created team =  (_71718:Team {team_id: 'NYN', team_name: 'New York Mets'})
# {'teamid': 'OAK', 'name': 'Oakland Athletics'}
# Created team =  (_71719:Team {team_id: 'OAK', team_name: 'Oakland Athletics'})
# {'teamid': 'PHI', 'name': 'Philadelphia Phillies'}
# Created team =  (_71720:Team {team_id: 'PHI', team_name: 'Philadelphia Phillies'})
# {'teamid': 'PIT', 'name': 'Pittsburgh Pirates'}
# Created team =  (_71721:Team {team_id: 'PIT', team_name: 'Pittsburgh Pirates'})
# {'teamid': 'SDN', 'name': 'San Diego Padres'}
# Created team =  (_71722:Team {team_id: 'SDN', team_name: 'San Diego Padres'})
# {'teamid': 'SEA', 'name': 'Seattle Mariners'}
# Created team =  (_71723:Team {team_id: 'SEA', team_name: 'Seattle Mariners'})
# {'teamid': 'SFN', 'name': 'San Francisco Giants'}
# Created team =  (_71724:Team {team_id: 'SFN', team_name: 'San Francisco Giants'})
# {'teamid': 'SLN', 'name': 'St. Louis Cardinals'}
# Created team =  (_71725:Team {team_id: 'SLN', team_name: 'St. Louis Cardinals'})
# {'teamid': 'TBA', 'name': 'Tampa Bay Devil Rays'}
# Created team =  (_71726:Team {team_id: 'TBA', team_name: 'Tampa Bay Devil Rays'})
# {'teamid': 'TBA', 'name': 'Tampa Bay Rays'}
# Created team =  (_71727:Team {team_id: 'TBA', team_name: 'Tampa Bay Rays'})
# {'teamid': 'TEX', 'name': 'Texas Rangers'}
# Created team =  (_71728:Team {team_id: 'TEX', team_name: 'Texas Rangers'})
# {'teamid': 'TOR', 'name': 'Toronto Blue Jays'}
# Created team =  (_71729:Team {team_id: 'TOR', team_name: 'Toronto Blue Jays'})
# {'teamid': 'WAS', 'name': 'Washington Nationals'}
# Created team =  (_71730:Team {team_id: 'WAS', team_name: 'Washington Nationals'})
# Loaded  34 records.

# %% [markdown]
# - Same basic logic here, except the call to the FanGraph.create_appearance_all() creates a relationship 'APPEARED' with some properties, not a node.

# %%
raise NotImplementedError("Do not run this code fool!")

def load_appearances():

    q = \
    "SELECT distinct playerid, teamid, yearid, g_all as games " + \
    " from appearances where yearid >= 2010"

    curs = cnx.cursor()
    curs.execute(q)

    r = curs.fetchone()
    cnt = 0
    while r is not None:
        print(r)
        cnt += 1

        if r is not None:
            try:
                p = fg.create_appearance_all(team_id=r['teamid'], player_id=r['playerid'], \
                                        games=r['games'], year=r['yearid'])
                print("Created appearances = ", json.dumps(p))
            except Exception as e:
                print("Could not create.")
        r = curs.fetchone()

    print("Loaded ", cnt, "records.")

# %%
raise NotImplementedError("Do not run this code fool!")

load_appearances()
# Out:
# {'playerid': 'aardsda01', 'teamid': 'ATL', 'yearid': '2015', 'games': '33'}
# Created appearances =  null
# {'playerid': 'aardsda01', 'teamid': 'NYA', 'yearid': '2012', 'games': '1'}
# Created appearances =  null
# {'playerid': 'aardsda01', 'teamid': 'NYN', 'yearid': '2013', 'games': '43'}
# Created appearances =  null
# {'playerid': 'aardsda01', 'teamid': 'SEA', 'yearid': '2010', 'games': '53'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'BOS', 'yearid': '2016', 'games': '18'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'BOS', 'yearid': '2017', 'games': '48'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'HOU', 'yearid': '2010', 'games': '22'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'HOU', 'yearid': '2011', 'games': '29'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'HOU', 'yearid': '2012', 'games': '37'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'MIN', 'yearid': '2016', 'games': '39'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'OAK', 'yearid': '2014', 'games': '69'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'OAK', 'yearid': '2015', 'games': '62'}
# Created appearances =  null
# {'playerid': 'abadfe01', 'teamid': 'WAS', 'yearid': '2013', 'games': '39'}
# Created appearances =  null
# {'playerid': 'abreubo01', 'teamid': 'LAA', 'yearid': '2010', 'games': '154'}
# Created appearances =  null
# {'playerid': 'abreubo01', 'teamid': 'LAA', 'yearid': '2011', 'games': '142'}
# Created appearances =  null
# {'playerid': 'abreubo01', 'teamid': 'LAA', 'yearid': '2012', 'games': '8'}
# Created appearances =  null
# {'playerid': 'abreubo01', 'teamid': 'LAN', 'yearid': '2012', 'games': '92'}
# Created appearances =  null
# {'playerid': 'abreubo01', 'teamid': 'NYN', 'yearid': '2014', 'games': '78'}
# Created appearances =  null
# {'playerid': 'abreujo02', 'teamid': 'CHA', 'yearid': '2014', 'games': '145'}
# Created appearances =  null
# {'playerid': 'abreujo02', 'teamid': 'CHA', 'yearid': '2015', 'games': '154'}
# Created appearances =  null
# {'playerid': 'abreujo02', 'teamid': 'CHA', 'yearid': '2016', 'games': '159'}
# Created appearances =  null
# {'playerid': 'abreujo02', 'teamid': 'CHA', 'yearid': '2017', 'games': '156'}
# Created appearances =  null
# {'playerid': 'abreuju01', 'teamid': 'HOU', 'yearid': '2011', 'games': '7'}
# Created appearances =  null
# {'playerid': 'abreuto01', 'teamid': 'ARI', 'yearid': '2010', 'games': '81'}
# Created appearances =  null
# {'playerid': 'abreuto01', 'teamid': 'KCA', 'yearid': '2012', 'games': '22'}
# Created appearances =  null
# {'playerid': 'abreuto01', 'teamid': 'SFN', 'yearid': '2013', 'games': '53'}
# Created appearances =  null
# {'playerid': 'abreuto01', 'teamid': 'SFN', 'yearid': '2014', 'games': '3'}
# Created appearances =  null
# {'playerid': 'accarje01', 'teamid': 'BAL', 'yearid': '2011', 'games': '31'}
# Created appearances =  null
# {'playerid': 'accarje01', 'teamid': 'CLE', 'yearid': '2012', 'games': '26'}
# Created appearances =  null
# {'playerid': 'accarje01', 'teamid': 'OAK', 'yearid': '2012', 'games': '1'}
# Created appearances =  null
# {'playerid': 'accarje01', 'teamid': 'TOR', 'yearid': '2010', 'games': '5'}
# Created appearances =  null
# {'playerid': 'aceveal01', 'teamid': 'BOS', 'yearid': '2011', 'games': '55'}
# Created appearances =  null
# {'playerid': 'aceveal01', 'teamid': 'BOS', 'yearid': '2012', 'games': '69'}
# Created appearances =  null
# {'playerid': 'aceveal01', 'teamid': 'BOS', 'yearid': '2013', 'games': '11'}
# Created appearances =  null
# {'playerid': 'aceveal01', 'teamid': 'NYA', 'yearid': '2010', 'games': '10'}
# Created appearances =  null
# {'playerid': 'aceveal01', 'teamid': 'NYA', 'yearid': '2014', 'games': '10'}
# Created appearances =  null
# {'playerid': 'achteaj01', 'teamid': 'LAA', 'yearid': '2016', 'games': '27'}
# Created appearances =  null
# {'playerid': 'achteaj01', 'teamid': 'MIN', 'yearid': '2014', 'games': '7'}
# Created appearances =  null
# {'playerid': 'achteaj01', 'teamid': 'MIN', 'yearid': '2015', 'games': '11'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'NYA', 'yearid': '2015', 'games': '23'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'NYA', 'yearid': '2016', 'games': '28'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'SEA', 'yearid': '2011', 'games': '90'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'SEA', 'yearid': '2012', 'games': '153'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'SEA', 'yearid': '2013', 'games': '113'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'SEA', 'yearid': '2014', 'games': '143'}
# Created appearances =  null
# {'playerid': 'ackledu01', 'teamid': 'SEA', 'yearid': '2015', 'games': '85'}
# Created appearances =  null
# {'playerid': 'acostma01', 'teamid': 'NYN', 'yearid': '2010', 'games': '41'}
# Created appearances =  null
# {'playerid': 'acostma01', 'teamid': 'NYN', 'yearid': '2011', 'games': '44'}
# Created appearances =  null
# {'playerid': 'acostma01', 'teamid': 'NYN', 'yearid': '2012', 'games': '45'}
# Created appearances =  null
# {'playerid': 'adamecr01', 'teamid': 'COL', 'yearid': '2014', 'games': '7'}
# Created appearances =  null
# {'playerid': 'adamecr01', 'teamid': 'COL', 'yearid': '2015', 'games': '26'}
# Created appearances =  null
# {'playerid': 'adamecr01', 'teamid': 'COL', 'yearid': '2016', 'games': '121'}
# Created appearances =  null
# {'playerid': 'adamecr01', 'teamid': 'COL', 'yearid': '2017', 'games': '12'}
# Created appearances =  null
# {'playerid': 'adamsau01', 'teamid': 'CLE', 'yearid': '2014', 'games': '6'}
# Created appearances =  null
# {'playerid': 'adamsau01', 'teamid': 'CLE', 'yearid': '2015', 'games': '28'}
# Created appearances =  null
# {'playerid': 'adamsau01', 'teamid': 'CLE', 'yearid': '2016', 'games': '19'}
# Created appearances =  null
# {'playerid': 'adamsau02', 'teamid': 'WAS', 'yearid': '2017', 'games': '6'}
# Created appearances =  null
# {'playerid': 'adamsda02', 'teamid': 'NYA', 'yearid': '2013', 'games': '43'}
# Created appearances =  null
# {'playerid': 'adamsla01', 'teamid': 'ATL', 'yearid': '2017', 'games': '85'}
# Created appearances =  null
# {'playerid': 'adamsla01', 'teamid': 'KCA', 'yearid': '2014', 'games': '6'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'ATL', 'yearid': '2017', 'games': '100'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2012', 'games': '27'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2013', 'games': '108'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2014', 'games': '142'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2015', 'games': '60'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2016', 'games': '118'}
# Created appearances =  null
# {'playerid': 'adamsma01', 'teamid': 'SLN', 'yearid': '2017', 'games': '31'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'PHI', 'yearid': '2013', 'games': '28'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'PHI', 'yearid': '2014', 'games': '22'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'SDN', 'yearid': '2010', 'games': '70'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'SDN', 'yearid': '2011', 'games': '49'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'TEX', 'yearid': '2011', 'games': '27'}
# Created appearances =  null
# {'playerid': 'adamsmi03', 'teamid': 'TEX', 'yearid': '2012', 'games': '61'}
# Created appearances =  null
# {'playerid': 'adamsry01', 'teamid': 'BAL', 'yearid': '2011', 'games': '29'}
# Created appearances =  null
# {'playerid': 'adcocna01', 'teamid': 'CIN', 'yearid': '2015', 'games': '13'}
# Created appearances =  null
# {'playerid': 'adcocna01', 'teamid': 'KCA', 'yearid': '2011', 'games': '24'}
# Created appearances =  null
# {'playerid': 'adcocna01', 'teamid': 'KCA', 'yearid': '2012', 'games': '12'}
# Created appearances =  null
# {'playerid': 'adcocna01', 'teamid': 'TEX', 'yearid': '2014', 'games': '7'}
# Created appearances =  null
# {'playerid': 'adducji02', 'teamid': 'DET', 'yearid': '2017', 'games': '29'}
# Created appearances =  null
# {'playerid': 'adducji02', 'teamid': 'TEX', 'yearid': '2013', 'games': '17'}
# Created appearances =  null
# {'playerid': 'adducji02', 'teamid': 'TEX', 'yearid': '2014', 'games': '44'}
# Created appearances =  null
# {'playerid': 'adlemti01', 'teamid': 'CIN', 'yearid': '2016', 'games': '13'}
# Created appearances =  null
# {'playerid': 'adlemti01', 'teamid': 'CIN', 'yearid': '2017', 'games': '30'}
# Created appearances =  null
# {'playerid': 'adriaeh01', 'teamid': 'MIN', 'yearid': '2017', 'games': '70'}
# Created appearances =  null
# {'playerid': 'adriaeh01', 'teamid': 'SFN', 'yearid': '2013', 'games': '9'}
# Created appearances =  null
# {'playerid': 'adriaeh01', 'teamid': 'SFN', 'yearid': '2014', 'games': '53'}
# Created appearances =  null
# {'playerid': 'adriaeh01', 'teamid': 'SFN', 'yearid': '2015', 'games': '52'}
# Created appearances =  null
# {'playerid': 'adriaeh01', 'teamid': 'SFN', 'yearid': '2016', 'games': '40'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2010', 'games': '53'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2011', 'games': '67'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2012', 'games': '67'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2013', 'games': '39'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2014', 'games': '62'}
# Created appearances =  null
# {'playerid': 'affelje01', 'teamid': 'SFN', 'yearid': '2015', 'games': '52'}
# Created appearances =  null
# {'playerid': 'aguilje01', 'teamid': 'CLE', 'yearid': '2014', 'games': '19'}
# Created appearances =  null
# {'playerid': 'aguilje01', 'teamid': 'CLE', 'yearid': '2015', 'games': '7'}
# Created appearances =  null
# {'playerid': 'aguilje01', 'teamid': 'CLE', 'yearid': '2016', 'games': '9'}
# Created appearances =  null
# {'playerid': 'aguilje01', 'teamid': 'MIL', 'yearid': '2017', 'games': '133'}
# Created appearances =  null
# {'playerid': 'ahmedni01', 'teamid': 'ARI', 'yearid': '2014', 'games': '25'}
# Created appearances =  null
# {'playerid': 'ahmedni01', 'teamid': 'ARI', 'yearid': '2015', 'games': '134'}
# Created appearances =  null
# {'playerid': 'ahmedni01', 'teamid': 'ARI', 'yearid': '2016', 'games': '90'}
# Created appearances =  null
# {'playerid': 'ahmedni01', 'teamid': 'ARI', 'yearid': '2017', 'games': '53'}
# Created appearances =  null
# {'playerid': 'albaljo01', 'teamid': 'ARI', 'yearid': '2012', 'games': '3'}
# Created appearances =  null
# {'playerid': 'albaljo01', 'teamid': 'NYA', 'yearid': '2010', 'games': '10'}
# Created appearances =  null
# {'playerid': 'alberan01', 'teamid': 'MIN', 'yearid': '2013', 'games': '10'}
# Created appearances =  null
# {'playerid': 'alberan01', 'teamid': 'MIN', 'yearid': '2016', 'games': '6'}
# Created appearances =  null
# {'playerid': 'alberan01', 'teamid': 'SEA', 'yearid': '2017', 'games': '9'}
# Created appearances =  null
# {'playerid': 'alberan01', 'teamid': 'TOR', 'yearid': '2015', 'games': '1'}
# Created appearances =  null
# {'playerid': 'alberha01', 'teamid': 'TEX', 'yearid': '2015', 'games': '41'}
# Created appearances =  null
# {'playerid': 'alberha01', 'teamid': 'TEX', 'yearid': '2016', 'games': '35'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'ARI', 'yearid': '2012', 'games': '23'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'BAL', 'yearid': '2010', 'games': '62'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'BOS', 'yearid': '2011', 'games': '56'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'BOS', 'yearid': '2012', 'games': '40'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'CHA', 'yearid': '2015', 'games': '30'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'CHA', 'yearid': '2016', 'games': '58'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'CLE', 'yearid': '2013', 'games': '56'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'HOU', 'yearid': '2014', 'games': '8'}
# Created appearances =  null
# {'playerid': 'alberma01', 'teamid': 'WAS', 'yearid': '2017', 'games': '63'}
# Created appearances =  null
# {'playerid': 'albieoz01', 'teamid': 'ATL', 'yearid': '2017', 'games': '57'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'CHA', 'yearid': '2017', 'games': '10'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'DET', 'yearid': '2011', 'games': '41'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'DET', 'yearid': '2012', 'games': '8'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'DET', 'yearid': '2013', 'games': '53'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'DET', 'yearid': '2014', 'games': '72'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'DET', 'yearid': '2015', 'games': '67'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'KCA', 'yearid': '2017', 'games': '11'}
# Created appearances =  null
# {'playerid': 'albural01', 'teamid': 'LAA', 'yearid': '2016', 'games': '2'}
# Created appearances =  null
# {'playerid': 'alcanar01', 'teamid': 'CHN', 'yearid': '2014', 'games': '70'}
# Created appearances =  null
# {'playerid': 'alcanar01', 'teamid': 'CHN', 'yearid': '2015', 'games': '11'}
# Created appearances =  null
# {'playerid': 'alcanar01', 'teamid': 'CIN', 'yearid': '2017', 'games': '70'}
# Created appearances =  null
# {'playerid': 'alcanar01', 'teamid': 'OAK', 'yearid': '2016', 'games': '16'}
# Created appearances =  null
# {'playerid': 'alcanra01', 'teamid': 'OAK', 'yearid': '2016', 'games': '5'}
# Created appearances =  null
# {'playerid': 'alcanra01', 'teamid': 'OAK', 'yearid': '2017', 'games': '8'}
# Created appearances =  null
# {'playerid': 'alcansa01', 'teamid': 'SLN', 'yearid': '2017', 'games': '8'}
# Created appearances =  null
# {'playerid': 'alcanvi01', 'teamid': 'DET', 'yearid': '2017', 'games': '6'}
# Created appearances =  null
# {'playerid': 'aldrico01', 'teamid': 'LAA', 'yearid': '2010', 'games': '5'}
# Created appearances =  null
# {'playerid': 'alexasc01', 'teamid': 'KCA', 'yearid': '2015', 'games': '4'}
# Created appearances =  null
# {'playerid': 'alexasc01', 'teamid': 'KCA', 'yearid': '2016', 'games': '17'}
# Created appearances =  null
# {'playerid': 'alexasc01', 'teamid': 'KCA', 'yearid': '2017', 'games': '58'}
# Created appearances =  null
# {'playerid': 'alfarjo01', 'teamid': 'PHI', 'yearid': '2016', 'games': '6'}
# Created appearances =  null
# {'playerid': 'alfarjo01', 'teamid': 'PHI', 'yearid': '2017', 'games': '29'}
# Created appearances =  null
# {'playerid': 'alfonel01', 'teamid': 'COL', 'yearid': '2011', 'games': '25'}
# Created appearances =  null
# {'playerid': 'alfonel01', 'teamid': 'SEA', 'yearid': '2010', 'games': '13'}
# Created appearances =  null
# {'playerid': 'alforan01', 'teamid': 'TOR', 'yearid': '2017', 'games': '4'}
# Created appearances =  null
# {'playerid': 'allenbr01', 'teamid': 'ARI', 'yearid': '2010', 'games': '22'}
# Created appearances =  null
# {'playerid': 'allenbr01', 'teamid': 'ARI', 'yearid': '2011', 'games': '11'}
# Created appearances =  null
# {'playerid': 'allenbr01', 'teamid': 'OAK', 'yearid': '2011', 'games': '41'}
# Created appearances =  null
# {'playerid': 'allenbr01', 'teamid': 'OAK', 'yearid': '2012', 'games': '3'}
# Created appearances =  null
# {'playerid': 'allenbr01', 'teamid': 'TBA', 'yearid': '2012', 'games': '7'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2012', 'games': '27'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2013', 'games': '77'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2014', 'games': '76'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2015', 'games': '70'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2016', 'games': '67'}
# Created appearances =  null
# {'playerid': 'allenco01', 'teamid': 'CLE', 'yearid': '2017', 'games': '69'}
# Created appearances =  null
# {'playerid': 'allengr01', 'teamid': 'CLE', 'yearid': '2017', 'games': '25'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'CLE', 'yearid': '2015', 'games': '51'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'CLE', 'yearid': '2016', 'games': '67'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'CLE', 'yearid': '2017', 'games': '69'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'SDN', 'yearid': '2014', 'games': '32'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'SDN', 'yearid': '2015', 'games': '31'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'SEA', 'yearid': '2013', 'games': '25'}
# Created appearances =  null
# {'playerid': 'almonab01', 'teamid': 'SEA', 'yearid': '2014', 'games': '27'}
# Created appearances =  null
# {'playerid': 'almoner01', 'teamid': 'MIL', 'yearid': '2011', 'games': '16'}
# Created appearances =  null
# {'playerid': 'almonmi01', 'teamid': 'KCA', 'yearid': '2015', 'games': '9'}
# Created appearances =  null
# {'playerid': 'almonmi01', 'teamid': 'KCA', 'yearid': '2017', 'games': '2'}
# Created appearances =  null
# {'playerid': 'almonzo01', 'teamid': 'NYA', 'yearid': '2013', 'games': '34'}
# Created appearances =  null
# {'playerid': 'almonzo01', 'teamid': 'NYA', 'yearid': '2014', 'games': '13'}
# Created appearances =  null
# {'playerid': 'almoral01', 'teamid': 'CHN', 'yearid': '2016', 'games': '47'}
# Created appearances =  null
# {'playerid': 'almoral01', 'teamid': 'CHN', 'yearid': '2017', 'games': '132'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'CIN', 'yearid': '2010', 'games': '22'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'CIN', 'yearid': '2011', 'games': '47'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'OAK', 'yearid': '2016', 'games': '156'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'OAK', 'yearid': '2017', 'games': '100'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'SDN', 'yearid': '2012', 'games': '155'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'SDN', 'yearid': '2013', 'games': '97'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'SDN', 'yearid': '2014', 'games': '84'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'SDN', 'yearid': '2015', 'games': '103'}
# Created appearances =  null
# {'playerid': 'alonsyo01', 'teamid': 'SEA', 'yearid': '2017', 'games': '42'}
# Created appearances =  null
# {'playerid': 'altavda01', 'teamid': 'SEA', 'yearid': '2016', 'games': '15'}
# Created appearances =  null
# {'playerid': 'altavda01', 'teamid': 'SEA', 'yearid': '2017', 'games': '41'}
# Created appearances =  null
# {'playerid': 'altheaa01', 'teamid': 'PHI', 'yearid': '2014', 'games': '2'}
# Created appearances =  null
# {'playerid': 'altheaa01', 'teamid': 'PHI', 'yearid': '2015', 'games': '39'}
# Created appearances =  null
# {'playerid': 'altheaa01', 'teamid': 'PHI', 'yearid': '2016', 'games': '57'}
# Created appearances =  null
# {'playerid': 'altheaa01', 'teamid': 'PHI', 'yearid': '2017', 'games': '107'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2011', 'games': '57'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2012', 'games': '147'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2013', 'games': '152'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2014', 'games': '158'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2015', 'games': '154'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2016', 'games': '161'}
# Created appearances =  null
# {'playerid': 'altuvjo01', 'teamid': 'HOU', 'yearid': '2017', 'games': '153'}
# Created appearances =  null
# {'playerid': 'alvarda01', 'teamid': 'ATL', 'yearid': '2016', 'games': '16'}
# Created appearances =  null
# {'playerid': 'alvarda01', 'teamid': 'NYN', 'yearid': '2014', 'games': '4'}
# Created appearances =  null
# {'playerid': 'alvarda01', 'teamid': 'NYN', 'yearid': '2015', 'games': '6'}
# Created appearances =  null
# {'playerid': 'alvarda01', 'teamid': 'TEX', 'yearid': '2016', 'games': '10'}
# Created appearances =  null
# {'playerid': 'alvarda01', 'teamid': 'TEX', 'yearid': '2017', 'games': '20'}
# Created appearances =  null
# {'playerid': 'alvarda02', 'teamid': 'BAL', 'yearid': '2015', 'games': '12'}
# Created appearances =  null
# {'playerid': 'alvarda02', 'teamid': 'BAL', 'yearid': '2016', 'games': '2'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'MIA', 'yearid': '2013', 'games': '17'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'MIA', 'yearid': '2014', 'games': '30'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'MIA', 'yearid': '2015', 'games': '4'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'PHI', 'yearid': '2017', 'games': '3'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'TOR', 'yearid': '2011', 'games': '10'}
# Created appearances =  null
# {'playerid': 'alvarhe01', 'teamid': 'TOR', 'yearid': '2012', 'games': '31'}
# Created appearances =  null
# {'playerid': 'alvarjo02', 'teamid': 'DET', 'yearid': '2013', 'games': '14'}
# Created appearances =  null
# {'playerid': 'alvarjo02', 'teamid': 'LAA', 'yearid': '2014', 'games': '2'}
# Created appearances =  null
# {'playerid': 'alvarjo02', 'teamid': 'LAA', 'yearid': '2015', 'games': '64'}
# Created appearances =  null
# {'playerid': 'alvarjo02', 'teamid': 'LAA', 'yearid': '2016', 'games': '64'}
# Created appearances =  null
# {'playerid': 'alvarjo02', 'teamid': 'LAA', 'yearid': '2017', 'games': '64'}
# Created appearances =  null
# {'playerid': 'alvarjo03', 'teamid': 'TBA', 'yearid': '2017', 'games': '35'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'BAL', 'yearid': '2016', 'games': '109'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'BAL', 'yearid': '2017', 'games': '14'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2010', 'games': '95'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2011', 'games': '74'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2012', 'games': '149'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2013', 'games': '152'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2014', 'games': '122'}
# Created appearances =  null
# {'playerid': 'alvarpe01', 'teamid': 'PIT', 'yearid': '2015', 'games': '150'}
# Created appearances =  null
# {'playerid': 'alvarrj01', 'teamid': 'OAK', 'yearid': '2015', 'games': '21'}
# Created appearances =  null
# {'playerid': 'alvarrj01', 'teamid': 'SDN', 'yearid': '2014', 'games': '10'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'COL', 'yearid': '2017', 'games': '96'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'LAA', 'yearid': '2011', 'games': '23'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'LAA', 'yearid': '2012', 'games': '1'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'SDN', 'yearid': '2012', 'games': '105'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'SDN', 'yearid': '2013', 'games': '146'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'SDN', 'yearid': '2014', 'games': '148'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'SDN', 'yearid': '2015', 'games': '118'}
# Created appearances =  null
# {'playerid': 'amarial01', 'teamid': 'SDN', 'yearid': '2016', 'games': '65'}
# Created appearances =  null
# {'playerid': 'ambrihe01', 'teamid': 'CLE', 'yearid': '2010', 'games': '34'}
# Created appearances =  null
# {'playerid': 'ambrihe01', 'teamid': 'HOU', 'yearid': '2012', 'games': '18'}
# Created appearances =  null
# {'playerid': 'ambrihe01', 'teamid': 'HOU', 'yearid': '2013', 'games': '43'}
# Created appearances =  null
# {'playerid': 'ambrihe01', 'teamid': 'SDN', 'yearid': '2014', 'games': '1'}
# Created appearances =  null
# {'playerid': 'amesst01', 'teamid': 'MIA', 'yearid': '2013', 'games': '4'}
# Created appearances =  null
# {'playerid': 'amezaal01', 'teamid': 'COL', 'yearid': '2011', 'games': '20'}
# Created appearances =  null
# {'playerid': 'amezaal01', 'teamid': 'FLO', 'yearid': '2011', 'games': '20'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'CHN', 'yearid': '2017', 'games': '6'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'COL', 'yearid': '2014', 'games': '8'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'LAN', 'yearid': '2015', 'games': '31'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'LAN', 'yearid': '2016', 'games': '4'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'OAK', 'yearid': '2010', 'games': '19'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'OAK', 'yearid': '2011', 'games': '13'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'OAK', 'yearid': '2012', 'games': '6'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'OAK', 'yearid': '2013', 'games': '16'}
# Created appearances =  null
# {'playerid': 'anderbr04', 'teamid': 'TOR', 'yearid': '2017', 'games': '7'}
# Created appearances =  null
# {'playerid': 'anderbr05', 'teamid': 'CHA', 'yearid': '2013', 'games': '10'}
# Created appearances =  null
# {'playerid': 'anderbr05', 'teamid': 'OAK', 'yearid': '2014', 'games': '1'}
# Created appearances =  null
# {'playerid': 'anderbr05', 'teamid': 'OAK', 'yearid': '2015', 'games': '4'}
# Created appearances =  null
# {'playerid': 'anderbr05', 'teamid': 'SLN', 'yearid': '2010', 'games': '15'}
# Created appearances =  null
# {'playerid': 'anderbr05', 'teamid': 'SLN', 'yearid': '2012', 'games': '10'}
# Created appearances =  null
# {'playerid': 'anderbr06', 'teamid': 'MIA', 'yearid': '2017', 'games': '25'}
# Created appearances =  null
# {'playerid': 'anderch01', 'teamid': 'ARI', 'yearid': '2014', 'games': '22'}
# Created appearances =  null
# {'playerid': 'anderch01', 'teamid': 'ARI', 'yearid': '2015', 'games': '28'}
# Created appearances =  null
# {'playerid': 'anderch01', 'teamid': 'MIL', 'yearid': '2016', 'games': '31'}
# Created appearances =  null
# {'playerid': 'anderch01', 'teamid': 'MIL', 'yearid': '2017', 'games': '25'}
# Created appearances =  null
# {'playerid': 'anderco01', 'teamid': 'CLE', 'yearid': '2015', 'games': '15'}
# Created appearances =  null
# {'playerid': 'anderco01', 'teamid': 'CLE', 'yearid': '2016', 'games': '19'}
# Created appearances =  null
# {'playerid': 'anderdr02', 'teamid': 'PHI', 'yearid': '2017', 'games': '2'}
# Created appearances =  null
# {'playerid': 'anderga01', 'teamid': 'LAN', 'yearid': '2010', 'games': '80'}
# Created appearances =  null
# {'playerid': 'anderla03', 'teamid': 'BOS', 'yearid': '2010', 'games': '18'}
# Created appearances =  null
# {'playerid': 'anderla03', 'teamid': 'BOS', 'yearid': '2011', 'games': '6'}
# Created appearances =  null
# {'playerid': 'anderla03', 'teamid': 'BOS', 'yearid': '2012', 'games': '6'}
# Created appearances =  null
# {'playerid': 'anderti01', 'teamid': 'CHA', 'yearid': '2016', 'games': '99'}
# Created appearances =  null
# {'playerid': 'anderti01', 'teamid': 'CHA', 'yearid': '2017', 'games': '146'}
# Created appearances =  null
# {'playerid': 'anderty01', 'teamid': 'COL', 'yearid': '2016', 'games': '20'}
# Created appearances =  null
# {'playerid': 'anderty01', 'teamid': 'COL', 'yearid': '2017', 'games': '17'}
# Created appearances =  null
# {'playerid': 'andinro01', 'teamid': 'BAL', 'yearid': '2010', 'games': '16'}
# Created appearances =  null
# {'playerid': 'andinro01', 'teamid': 'BAL', 'yearid': '2011', 'games': '139'}
# Created appearances =  null
# {'playerid': 'andinro01', 'teamid': 'BAL', 'yearid': '2012', 'games': '127'}
# Created appearances =  null
# {'playerid': 'andinro01', 'teamid': 'MIA', 'yearid': '2016', 'games': '13'}
# Created appearances =  null
# {'playerid': 'andinro01', 'teamid': 'SEA', 'yearid': '2013', 'games': '29'}
# Created appearances =  null
# {'playerid': 'andrima01', 'teamid': 'TBA', 'yearid': '2015', 'games': '25'}
# Created appearances =  null
# {'playerid': 'andrima01', 'teamid': 'TBA', 'yearid': '2016', 'games': '29'}
# Created appearances =  null
# {'playerid': 'andrima01', 'teamid': 'TBA', 'yearid': '2017', 'games': '18'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2010', 'games': '148'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2011', 'games': '150'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2012', 'games': '158'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2013', 'games': '156'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2014', 'games': '157'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2015', 'games': '160'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2016', 'games': '147'}
# Created appearances =  null
# {'playerid': 'andruel01', 'teamid': 'TEX', 'yearid': '2017', 'games': '158'}
# Created appearances =  null
# {'playerid': 'andujmi01', 'teamid': 'NYA', 'yearid': '2017', 'games': '5'}
# Created appearances =  null
# {'playerid': 'anglema01', 'teamid': 'BAL', 'yearid': '2011', 'games': '31'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'ATL', 'yearid': '2010', 'games': '47'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'HOU', 'yearid': '2013', 'games': '25'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'KCA', 'yearid': '2010', 'games': '27'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'NYN', 'yearid': '2013', 'games': '20'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'WAS', 'yearid': '2011', 'games': '122'}
# Created appearances =  null
# {'playerid': 'ankieri01', 'teamid': 'WAS', 'yearid': '2012', 'games': '68'}
# Created appearances =  null
# {'playerid': 'annade01', 'teamid': 'NYA', 'yearid': '2014', 'games': '12'}
# Created appearances =  null
# {'playerid': 'annade01', 'teamid': 'SLN', 'yearid': '2015', 'games': '1'}
# Created appearances =  null
# {'playerid': 'antoldu01', 'teamid': 'TOR', 'yearid': '2016', 'games': '1'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'HOU', 'yearid': '2017', 'games': '71'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'KCA', 'yearid': '2014', 'games': '132'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'MIL', 'yearid': '2012', 'games': '151'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'MIL', 'yearid': '2013', 'games': '155'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'NYN', 'yearid': '2017', 'games': '27'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'SEA', 'yearid': '2016', 'games': '118'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'SFN', 'yearid': '2015', 'games': '93'}
# Created appearances =  null
# {'playerid': 'aokino01', 'teamid': 'TOR', 'yearid': '2017', 'games': '12'}
# Created appearances =  null
# {'playerid': 'aquinja01', 'teamid': 'BAL', 'yearid': '2016', 'games': '3'}
# Created appearances =  null
# {'playerid': 'aquinja01', 'teamid': 'BAL', 'yearid': '2017', 'games': '4'}
# Created appearances =  null
# {'playerid': 'aranovi01', 'teamid': 'PHI', 'yearid': '2017', 'games': '10'}
# Created appearances =  null
# {'playerid': 'araujel01', 'teamid': 'PHI', 'yearid': '2015', 'games': '40'}
# Created appearances =  null
# {'playerid': 'araujel01', 'teamid': 'PHI', 'yearid': '2016', 'games': '32'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2012', 'games': '8'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2013', 'games': '23'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2014', 'games': '32'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2015', 'games': '34'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2016', 'games': '33'}
# Created appearances =  null
# {'playerid': 'archech01', 'teamid': 'TBA', 'yearid': '2017', 'games': '34'}
# Created appearances =  null
# {'playerid': 'arciaor01', 'teamid': 'MIL', 'yearid': '2016', 'games': '55'}
# Created appearances =  null
# {'playerid': 'arciaor01', 'teamid': 'MIL', 'yearid': '2017', 'games': '153'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'MIA', 'yearid': '2016', 'games': '2'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'MIN', 'yearid': '2013', 'games': '97'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'MIN', 'yearid': '2014', 'games': '103'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'MIN', 'yearid': '2015', 'games': '19'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'MIN', 'yearid': '2016', 'games': '32'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'SDN', 'yearid': '2016', 'games': '14'}
# Created appearances =  null
# {'playerid': 'arciaos01', 'teamid': 'TBA', 'yearid': '2016', 'games': '21'}
# Created appearances =  null
# {'playerid': 'arenano01', 'teamid': 'COL', 'yearid': '2013', 'games': '133'}
# Created appearances =  null
# {'playerid': 'arenano01', 'teamid': 'COL', 'yearid': '2014', 'games': '111'}
# Created appearances =  null
# {'playerid': 'arenano01', 'teamid': 'COL', 'yearid': '2015', 'games': '157'}
# Created appearances =  null
# {'playerid': 'arenano01', 'teamid': 'COL', 'yearid': '2016', 'games': '160'}
# Created appearances =  null
# {'playerid': 'arenano01', 'teamid': 'COL', 'yearid': '2017', 'games': '159'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TBA', 'yearid': '2015', 'games': '24'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TEX', 'yearid': '2014', 'games': '63'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TOR', 'yearid': '2010', 'games': '11'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TOR', 'yearid': '2011', 'games': '129'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TOR', 'yearid': '2012', 'games': '102'}
# Created appearances =  null
# {'playerid': 'arencjp01', 'teamid': 'TOR', 'yearid': '2013', 'games': '138'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'NYN', 'yearid': '2010', 'games': '22'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'SFN', 'yearid': '2012', 'games': '112'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'SFN', 'yearid': '2013', 'games': '102'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'SFN', 'yearid': '2014', 'games': '107'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'SFN', 'yearid': '2015', 'games': '40'}
# Created appearances =  null
# {'playerid': 'ariasjo01', 'teamid': 'TEX', 'yearid': '2010', 'games': '50'}
# Created appearances =  null
# {'playerid': 'armstsh01', 'teamid': 'CLE', 'yearid': '2015', 'games': '8'}
# Created appearances =  null
# {'playerid': 'armstsh01', 'teamid': 'CLE', 'yearid': '2016', 'games': '10'}
# Created appearances =  null
# {'playerid': 'armstsh01', 'teamid': 'CLE', 'yearid': '2017', 'games': '21'}
# Created appearances =  null
# {'playerid': 'arojo01', 'teamid': 'BOS', 'yearid': '2015', 'games': '6'}
# Created appearances =  null
# {'playerid': 'arojo01', 'teamid': 'SEA', 'yearid': '2016', 'games': '1'}
# Created appearances =  null
# {'playerid': 'arredjo01', 'teamid': 'CIN', 'yearid': '2011', 'games': '53'}
# Created appearances =  null
# {'playerid': 'arredjo01', 'teamid': 'CIN', 'yearid': '2012', 'games': '66'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'BAL', 'yearid': '2010', 'games': '18'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'BAL', 'yearid': '2011', 'games': '22'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'BAL', 'yearid': '2012', 'games': '24'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'BAL', 'yearid': '2013', 'games': '5'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'CHN', 'yearid': '2013', 'games': '9'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'CHN', 'yearid': '2014', 'games': '26'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'CHN', 'yearid': '2015', 'games': '33'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'CHN', 'yearid': '2016', 'games': '31'}
# Created appearances =  null
# {'playerid': 'arrieja01', 'teamid': 'CHN', 'yearid': '2017', 'games': '32'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'ARI', 'yearid': '2014', 'games': '15'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'CIN', 'yearid': '2010', 'games': '34'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'CIN', 'yearid': '2011', 'games': '36'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'CIN', 'yearid': '2012', 'games': '32'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'CIN', 'yearid': '2013', 'games': '32'}
# Created appearances =  null
# {'playerid': 'arroybr01', 'teamid': 'CIN', 'yearid': '2017', 'games': '15'}
# Created appearances =  null
# {'playerid': 'arroych01', 'teamid': 'SFN', 'yearid': '2017', 'games': '34'}
# Created appearances =  null
# {'playerid': 'arrueer01', 'teamid': 'LAN', 'yearid': '2014', 'games': '22'}
# Created appearances =  null
# {'playerid': 'ascanjo01', 'teamid': 'PIT', 'yearid': '2011', 'games': '8'}
# Created appearances =  null
# {'playerid': 'ascheco01', 'teamid': 'CHA', 'yearid': '2017', 'games': '19'}
# Created appearances =  null
# {'playerid': 'ascheco01', 'teamid': 'PHI', 'yearid': '2013', 'games': '50'}
# Created appearances =  null
# {'playerid': 'ascheco01', 'teamid': 'PHI', 'yearid': '2014', 'games': '121'}
# Created appearances =  null
# {'playerid': 'ascheco01', 'teamid': 'PHI', 'yearid': '2015', 'games': '129'}
# Created appearances =  null
# {'playerid': 'ascheco01', 'teamid': 'PHI', 'yearid': '2016', 'games': '71'}
# Created appearances =  null
# {'playerid': 'asheral01', 'teamid': 'BAL', 'yearid': '2017', 'games': '24'}
# Created appearances =  null
# {'playerid': 'asheral01', 'teamid': 'PHI', 'yearid': '2015', 'games': '7'}
# Created appearances =  null
# {'playerid': 'asheral01', 'teamid': 'PHI', 'yearid': '2016', 'games': '5'}
# Created appearances =  null
# {'playerid': 'ashlene01', 'teamid': 'MIL', 'yearid': '2015', 'games': '12'}
# Created appearances =  null
# {'playerid': 'astinba01', 'teamid': 'CIN', 'yearid': '2017', 'games': '6'}
# Created appearances =  null
# {'playerid': 'asuajca01', 'teamid': 'SDN', 'yearid': '2016', 'games': '7'}
# Created appearances =  null
# {'playerid': 'asuajca01', 'teamid': 'SDN', 'yearid': '2017', 'games': '89'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'BOS', 'yearid': '2010', 'games': '43'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'BOS', 'yearid': '2011', 'games': '18'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'BOS', 'yearid': '2012', 'games': '42'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'CLE', 'yearid': '2014', 'games': '70'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'CLE', 'yearid': '2015', 'games': '23'}
# Created appearances =  null
# {'playerid': 'atchisc01', 'teamid': 'NYN', 'yearid': '2013', 'games': '51'}
# Created appearances =  null
# {'playerid': 'atilalu01', 'teamid': 'WAS', 'yearid': '2010', 'games': '16'}
# Created appearances =  null
# {'playerid': 'atkinga01', 'teamid': 'BAL', 'yearid': '2010', 'games': '44'}
# Created appearances =  null
# {'playerid': 'atkinmi01', 'teamid': 'BAL', 'yearid': '2011', 'games': '3'}
# Created appearances =  null
# {'playerid': 'atkinmi01', 'teamid': 'CHN', 'yearid': '2010', 'games': '5'}
# Created appearances =  null
# {'playerid': 'augenbr01', 'teamid': 'SLN', 'yearid': '2011', 'games': '5'}
# Created appearances =  null
# {'playerid': 'aumonph01', 'teamid': 'PHI', 'yearid': '2012', 'games': '18'}
# Created appearances =  null
# {'playerid': 'aumonph01', 'teamid': 'PHI', 'yearid': '2013', 'games': '22'}
# Created appearances =  null
# {'playerid': 'aumonph01', 'teamid': 'PHI', 'yearid': '2014', 'games': '5'}
# Created appearances =  null
# {'playerid': 'aumonph01', 'teamid': 'PHI', 'yearid': '2015', 'games': '1'}
# Created appearances =  null
# {'playerid': 'ausmubr01', 'teamid': 'LAN', 'yearid': '2010', 'games': '21'}
# Created appearances =  null
# {'playerid': 'austity01', 'teamid': 'NYA', 'yearid': '2016', 'games': '31'}
# Created appearances =  null
# {'playerid': 'austity01', 'teamid': 'NYA', 'yearid': '2017', 'games': '20'}
# Created appearances =  null
# {'playerid': 'averyxa01', 'teamid': 'BAL', 'yearid': '2012', 'games': '32'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'CHA', 'yearid': '2016', 'games': '57'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'CHN', 'yearid': '2017', 'games': '35'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2010', 'games': '104'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2011', 'games': '141'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2012', 'games': '116'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2013', 'games': '102'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2014', 'games': '124'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2015', 'games': '67'}
# Created appearances =  null
# {'playerid': 'avilaal01', 'teamid': 'DET', 'yearid': '2017', 'games': '77'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'ATL', 'yearid': '2012', 'games': '31'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'ATL', 'yearid': '2013', 'games': '75'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'ATL', 'yearid': '2014', 'games': '62'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'ATL', 'yearid': '2015', 'games': '50'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'LAN', 'yearid': '2015', 'games': '23'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'LAN', 'yearid': '2016', 'games': '27'}
# Created appearances =  null
# {'playerid': 'avilalu01', 'teamid': 'LAN', 'yearid': '2017', 'games': '61'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'BOS', 'yearid': '2011', 'games': '38'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'BOS', 'yearid': '2012', 'games': '136'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'CLE', 'yearid': '2013', 'games': '124'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'CLE', 'yearid': '2014', 'games': '113'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'CLE', 'yearid': '2015', 'games': '98'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'DET', 'yearid': '2016', 'games': '68'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'KCA', 'yearid': '2010', 'games': '110'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'KCA', 'yearid': '2011', 'games': '53'}
# Created appearances =  null
# {'playerid': 'avilemi01', 'teamid': 'MIA', 'yearid': '2017', 'games': '37'}
# Created appearances =  null
# {'playerid': 'axelrdy01', 'teamid': 'CHA', 'yearid': '2011', 'games': '4'}
# Created appearances =  null
# {'playerid': 'axelrdy01', 'teamid': 'CHA', 'yearid': '2012', 'games': '14'}
# Created appearances =  null
# {'playerid': 'axelrdy01', 'teamid': 'CHA', 'yearid': '2013', 'games': '30'}
# Created appearances =  null
# {'playerid': 'axelrdy01', 'teamid': 'CIN', 'yearid': '2014', 'games': '5'}
# Created appearances =  null
# {'playerid': 'axelrdy01', 'teamid': 'CIN', 'yearid': '2015', 'games': '6'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'CLE', 'yearid': '2014', 'games': '49'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'COL', 'yearid': '2015', 'games': '60'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'MIL', 'yearid': '2010', 'games': '50'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'MIL', 'yearid': '2011', 'games': '74'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'MIL', 'yearid': '2012', 'games': '75'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'MIL', 'yearid': '2013', 'games': '62'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'OAK', 'yearid': '2016', 'games': '68'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'OAK', 'yearid': '2017', 'games': '22'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'PIT', 'yearid': '2014', 'games': '13'}
# Created appearances =  null
# {'playerid': 'axforjo01', 'teamid': 'SLN', 'yearid': '2013', 'games': '13'}
# Created appearances =  null
# {'playerid': 'ayalalu01', 'teamid': 'ATL', 'yearid': '2013', 'games': '37'}
# Created appearances =  null
# {'playerid': 'ayalalu01', 'teamid': 'BAL', 'yearid': '2012', 'games': '66'}
# Created appearances =  null
# {'playerid': 'ayalalu01', 'teamid': 'BAL', 'yearid': '2013', 'games': '2'}
# Created appearances =  null
# {'playerid': 'ayalalu01', 'teamid': 'NYA', 'yearid': '2011', 'games': '52'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'ATL', 'yearid': '2016', 'games': '97'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'DET', 'yearid': '2016', 'games': '29'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2010', 'games': '138'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2011', 'games': '143'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2012', 'games': '141'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2013', 'games': '138'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2014', 'games': '156'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'LAA', 'yearid': '2015', 'games': '156'}
# Created appearances =  null
# {'playerid': 'aybarer01', 'teamid': 'SDN', 'yearid': '2017', 'games': '108'}
# Created appearances =  null
# {'playerid': 'aybarwi01', 'teamid': 'TBA', 'yearid': '2010', 'games': '100'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'BOS', 'yearid': '2014', 'games': '70'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'CIN', 'yearid': '2015', 'games': '68'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'FLO', 'yearid': '2010', 'games': '53'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'FLO', 'yearid': '2011', 'games': '50'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'MIL', 'yearid': '2013', 'games': '63'}
# Created appearances =  null
# {'playerid': 'badenbu01', 'teamid': 'TBA', 'yearid': '2012', 'games': '66'}
# Created appearances =  null
# {'playerid': 'baderha01', 'teamid': 'SLN', 'yearid': '2017', 'games': '32'}
# Created appearances =  null
# {'playerid': 'baezda01', 'teamid': 'PHI', 'yearid': '2010', 'games': '51'}
# Created appearances =  null
# {'playerid': 'baezda01', 'teamid': 'PHI', 'yearid': '2011', 'games': '29'}
# Created appearances =  null
# {'playerid': 'baezja01', 'teamid': 'CHN', 'yearid': '2014', 'games': '52'}
# Created appearances =  null
# {'playerid': 'baezja01', 'teamid': 'CHN', 'yearid': '2015', 'games': '28'}
# Created appearances =  null
# {'playerid': 'baezja01', 'teamid': 'CHN', 'yearid': '2016', 'games': '142'}
# Created appearances =  null
# {'playerid': 'baezja01', 'teamid': 'CHN', 'yearid': '2017', 'games': '145'}
# ...
# Created appearances =  null
# {'playerid': 'wrighja01', 'teamid': 'LAN', 'yearid': '2014', 'games': '61'}
# Created appearances =  null
# {'playerid': 'wrighja01', 'teamid': 'SEA', 'yearid': '2010', 'games': '28'}
# Created appearances =  null
# {'playerid': 'wrighja01', 'teamid': 'SEA', 'yearid': '2011', 'games': '60'}
# Created appearances =  null
# {'playerid': 'wrighja01', 'teamid': 'TBA', 'yearid': '2013', 'games': '66'}
# Created appearances =  null
# {'playerid': 'wrighmi01', 'teamid': 'BAL', 'yearid': '2015', 'games': '12'}
# Created appearances =  null
# {'playerid': 'wrighmi01', 'teamid': 'BAL', 'yearid': '2016', 'games': '18'}
# Created appearances =  null
# {'playerid': 'wrighmi01', 'teamid': 'BAL', 'yearid': '2017', 'games': '13'}
# Created appearances =  null
# {'playerid': 'wrighst01', 'teamid': 'BOS', 'yearid': '2013', 'games': '4'}
# Created appearances =  null
# {'playerid': 'wrighst01', 'teamid': 'BOS', 'yearid': '2014', 'games': '6'}
# Created appearances =  null
# {'playerid': 'wrighst01', 'teamid': 'BOS', 'yearid': '2015', 'games': '16'}
# Created appearances =  null
# {'playerid': 'wrighst01', 'teamid': 'BOS', 'yearid': '2016', 'games': '25'}
# Created appearances =  null
# {'playerid': 'wrighst01', 'teamid': 'BOS', 'yearid': '2017', 'games': '5'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'BAL', 'yearid': '2015', 'games': '2'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'CHN', 'yearid': '2014', 'games': '58'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'HOU', 'yearid': '2010', 'games': '14'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'HOU', 'yearid': '2011', 'games': '21'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'HOU', 'yearid': '2012', 'games': '78'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'HOU', 'yearid': '2013', 'games': '55'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'LAA', 'yearid': '2015', 'games': '9'}
# Created appearances =  null
# {'playerid': 'wrighwe01', 'teamid': 'TBA', 'yearid': '2013', 'games': '16'}
# Created appearances =  null
# {'playerid': 'wuertmi01', 'teamid': 'OAK', 'yearid': '2010', 'games': '48'}
# Created appearances =  null
# {'playerid': 'wuertmi01', 'teamid': 'OAK', 'yearid': '2011', 'games': '39'}
# Created appearances =  null
# {'playerid': 'yacabji01', 'teamid': 'BAL', 'yearid': '2017', 'games': '14'}
# Created appearances =  null
# {'playerid': 'yateski01', 'teamid': 'LAA', 'yearid': '2017', 'games': '1'}
# Created appearances =  null
# {'playerid': 'yateski01', 'teamid': 'NYA', 'yearid': '2016', 'games': '41'}
# Created appearances =  null
# {'playerid': 'yateski01', 'teamid': 'SDN', 'yearid': '2017', 'games': '61'}
# Created appearances =  null
# {'playerid': 'yateski01', 'teamid': 'TBA', 'yearid': '2014', 'games': '37'}
# Created appearances =  null
# {'playerid': 'yateski01', 'teamid': 'TBA', 'yearid': '2015', 'games': '20'}
# Created appearances =  null
# {'playerid': 'yelicch01', 'teamid': 'MIA', 'yearid': '2013', 'games': '62'}
# Created appearances =  null
# {'playerid': 'yelicch01', 'teamid': 'MIA', 'yearid': '2014', 'games': '144'}
# Created appearances =  null
# {'playerid': 'yelicch01', 'teamid': 'MIA', 'yearid': '2015', 'games': '126'}
# Created appearances =  null
# {'playerid': 'yelicch01', 'teamid': 'MIA', 'yearid': '2016', 'games': '155'}
# Created appearances =  null
# {'playerid': 'yelicch01', 'teamid': 'MIA', 'yearid': '2017', 'games': '156'}
# Created appearances =  null
# {'playerid': 'ynoaga01', 'teamid': 'BAL', 'yearid': '2017', 'games': '9'}
# Created appearances =  null
# {'playerid': 'ynoaga01', 'teamid': 'NYN', 'yearid': '2016', 'games': '10'}
# Created appearances =  null
# {'playerid': 'ynoami01', 'teamid': 'CHA', 'yearid': '2016', 'games': '23'}
# Created appearances =  null
# {'playerid': 'ynoami01', 'teamid': 'CHA', 'yearid': '2017', 'games': '22'}
# Created appearances =  null
# {'playerid': 'ynoara01', 'teamid': 'COL', 'yearid': '2014', 'games': '19'}
# Created appearances =  null
# {'playerid': 'ynoara01', 'teamid': 'COL', 'yearid': '2015', 'games': '72'}
# Created appearances =  null
# {'playerid': 'ynoara01', 'teamid': 'COL', 'yearid': '2016', 'games': '3'}
# Created appearances =  null
# {'playerid': 'youklke01', 'teamid': 'BOS', 'yearid': '2010', 'games': '102'}
# Created appearances =  null
# {'playerid': 'youklke01', 'teamid': 'BOS', 'yearid': '2011', 'games': '120'}
# Created appearances =  null
# {'playerid': 'youklke01', 'teamid': 'BOS', 'yearid': '2012', 'games': '42'}
# Created appearances =  null
# {'playerid': 'youklke01', 'teamid': 'CHA', 'yearid': '2012', 'games': '80'}
# Created appearances =  null
# {'playerid': 'youklke01', 'teamid': 'NYA', 'yearid': '2013', 'games': '28'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'KCA', 'yearid': '2015', 'games': '34'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'KCA', 'yearid': '2016', 'games': '34'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'KCA', 'yearid': '2017', 'games': '14'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'NYN', 'yearid': '2011', 'games': '4'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'NYN', 'yearid': '2012', 'games': '20'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'SDN', 'yearid': '2010', 'games': '4'}
# Created appearances =  null
# {'playerid': 'youngch03', 'teamid': 'SEA', 'yearid': '2014', 'games': '30'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'ARI', 'yearid': '2010', 'games': '156'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'ARI', 'yearid': '2011', 'games': '156'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'ARI', 'yearid': '2012', 'games': '101'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'BOS', 'yearid': '2016', 'games': '76'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'BOS', 'yearid': '2017', 'games': '90'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'NYA', 'yearid': '2014', 'games': '23'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'NYA', 'yearid': '2015', 'games': '140'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'NYN', 'yearid': '2014', 'games': '88'}
# Created appearances =  null
# {'playerid': 'youngch04', 'teamid': 'OAK', 'yearid': '2013', 'games': '107'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'BAL', 'yearid': '2014', 'games': '83'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'BAL', 'yearid': '2015', 'games': '52'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'DET', 'yearid': '2011', 'games': '40'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'DET', 'yearid': '2012', 'games': '151'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'MIN', 'yearid': '2010', 'games': '153'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'MIN', 'yearid': '2011', 'games': '84'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'PHI', 'yearid': '2013', 'games': '80'}
# Created appearances =  null
# {'playerid': 'youngde03', 'teamid': 'TBA', 'yearid': '2013', 'games': '23'}
# Created appearances =  null
# {'playerid': 'youngde04', 'teamid': 'PIT', 'yearid': '2010', 'games': '110'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'ATL', 'yearid': '2015', 'games': '35'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'COL', 'yearid': '2010', 'games': '51'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'COL', 'yearid': '2011', 'games': '77'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'COL', 'yearid': '2012', 'games': '98'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'COL', 'yearid': '2013', 'games': '57'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'LAA', 'yearid': '2017', 'games': '47'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'NYA', 'yearid': '2016', 'games': '6'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'NYN', 'yearid': '2013', 'games': '91'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'NYN', 'yearid': '2014', 'games': '100'}
# Created appearances =  null
# {'playerid': 'younger03', 'teamid': 'NYN', 'yearid': '2015', 'games': '18'}
# Created appearances =  null
# {'playerid': 'youngma02', 'teamid': 'ATL', 'yearid': '2011', 'games': '20'}
# Created appearances =  null
# {'playerid': 'youngma02', 'teamid': 'DET', 'yearid': '2012', 'games': '5'}
# Created appearances =  null
# {'playerid': 'youngma03', 'teamid': 'ATL', 'yearid': '2016', 'games': '8'}
# Created appearances =  null
# {'playerid': 'youngmi02', 'teamid': 'LAN', 'yearid': '2013', 'games': '21'}
# Created appearances =  null
# {'playerid': 'youngmi02', 'teamid': 'PHI', 'yearid': '2013', 'games': '126'}
# Created appearances =  null
# {'playerid': 'youngmi02', 'teamid': 'TEX', 'yearid': '2010', 'games': '157'}
# Created appearances =  null
# {'playerid': 'youngmi02', 'teamid': 'TEX', 'yearid': '2011', 'games': '159'}
# Created appearances =  null
# {'playerid': 'youngmi02', 'teamid': 'TEX', 'yearid': '2012', 'games': '156'}
# Created appearances =  null
# {'playerid': 'zagunma01', 'teamid': 'CHN', 'yearid': '2017', 'games': '7'}
# Created appearances =  null
# {'playerid': 'zagurmi01', 'teamid': 'ARI', 'yearid': '2012', 'games': '45'}
# Created appearances =  null
# {'playerid': 'zagurmi01', 'teamid': 'NYA', 'yearid': '2013', 'games': '1'}
# Created appearances =  null
# {'playerid': 'zagurmi01', 'teamid': 'PHI', 'yearid': '2010', 'games': '8'}
# Created appearances =  null
# {'playerid': 'zagurmi01', 'teamid': 'PHI', 'yearid': '2011', 'games': '4'}
# Created appearances =  null
# {'playerid': 'zagurmi01', 'teamid': 'PIT', 'yearid': '2013', 'games': '6'}
# Created appearances =  null
# {'playerid': 'zambrca01', 'teamid': 'CHN', 'yearid': '2010', 'games': '42'}
# Created appearances =  null
# {'playerid': 'zambrca01', 'teamid': 'CHN', 'yearid': '2011', 'games': '25'}
# Created appearances =  null
# {'playerid': 'zambrca01', 'teamid': 'MIA', 'yearid': '2012', 'games': '35'}
# Created appearances =  null
# {'playerid': 'zastrro01', 'teamid': 'CHN', 'yearid': '2016', 'games': '8'}
# Created appearances =  null
# {'playerid': 'zastrro01', 'teamid': 'CHN', 'yearid': '2017', 'games': '4'}
# Created appearances =  null
# {'playerid': 'zaungr01', 'teamid': 'MIL', 'yearid': '2010', 'games': '28'}
# Created appearances =  null
# {'playerid': 'zawadla01', 'teamid': 'SDN', 'yearid': '2010', 'games': '20'}
# Created appearances =  null
# {'playerid': 'zeidjo01', 'teamid': 'HOU', 'yearid': '2013', 'games': '25'}
# Created appearances =  null
# {'playerid': 'zeidjo01', 'teamid': 'HOU', 'yearid': '2014', 'games': '23'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2011', 'games': '23'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2012', 'games': '77'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2013', 'games': '78'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2014', 'games': '68'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2015', 'games': '66'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'ARI', 'yearid': '2016', 'games': '36'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'BOS', 'yearid': '2016', 'games': '33'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'MIA', 'yearid': '2017', 'games': '53'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'OAK', 'yearid': '2010', 'games': '64'}
# Created appearances =  null
# {'playerid': 'zieglbr01', 'teamid': 'OAK', 'yearid': '2011', 'games': '43'}
# Created appearances =  null
# {'playerid': 'zimmebr01', 'teamid': 'CLE', 'yearid': '2017', 'games': '101'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'DET', 'yearid': '2016', 'games': '19'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'DET', 'yearid': '2017', 'games': '29'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2010', 'games': '7'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2011', 'games': '29'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2012', 'games': '32'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2013', 'games': '32'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2014', 'games': '32'}
# Created appearances =  null
# {'playerid': 'zimmejo02', 'teamid': 'WAS', 'yearid': '2015', 'games': '33'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2010', 'games': '142'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2011', 'games': '101'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2012', 'games': '145'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2013', 'games': '147'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2014', 'games': '61'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2015', 'games': '95'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2016', 'games': '115'}
# Created appearances =  null
# {'playerid': 'zimmery01', 'teamid': 'WAS', 'yearid': '2017', 'games': '144'}
# Created appearances =  null
# {'playerid': 'zitoba01', 'teamid': 'OAK', 'yearid': '2015', 'games': '3'}
# Created appearances =  null
# {'playerid': 'zitoba01', 'teamid': 'SFN', 'yearid': '2010', 'games': '34'}
# Created appearances =  null
# {'playerid': 'zitoba01', 'teamid': 'SFN', 'yearid': '2011', 'games': '13'}
# Created appearances =  null
# {'playerid': 'zitoba01', 'teamid': 'SFN', 'yearid': '2012', 'games': '32'}
# Created appearances =  null
# {'playerid': 'zitoba01', 'teamid': 'SFN', 'yearid': '2013', 'games': '30'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'CHN', 'yearid': '2016', 'games': '147'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'CHN', 'yearid': '2017', 'games': '128'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'KCA', 'yearid': '2015', 'games': '59'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'OAK', 'yearid': '2015', 'games': '67'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'TBA', 'yearid': '2010', 'games': '151'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'TBA', 'yearid': '2011', 'games': '156'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'TBA', 'yearid': '2012', 'games': '157'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'TBA', 'yearid': '2013', 'games': '157'}
# Created appearances =  null
# {'playerid': 'zobribe01', 'teamid': 'TBA', 'yearid': '2014', 'games': '146'}
# Created appearances =  null
# {'playerid': 'zumayjo01', 'teamid': 'DET', 'yearid': '2010', 'games': '31'}
# Created appearances =  null
# {'playerid': 'zuninmi01', 'teamid': 'SEA', 'yearid': '2013', 'games': '52'}
# Created appearances =  null
# {'playerid': 'zuninmi01', 'teamid': 'SEA', 'yearid': '2014', 'games': '131'}
# Created appearances =  null
# {'playerid': 'zuninmi01', 'teamid': 'SEA', 'yearid': '2015', 'games': '112'}
# Created appearances =  null
# {'playerid': 'zuninmi01', 'teamid': 'SEA', 'yearid': '2016', 'games': '55'}
# Created appearances =  null
# {'playerid': 'zuninmi01', 'teamid': 'SEA', 'yearid': '2017', 'games': '124'}
# Created appearances =  null
# {'playerid': 'zychto01', 'teamid': 'SEA', 'yearid': '2015', 'games': '13'}
# Created appearances =  null
# {'playerid': 'zychto01', 'teamid': 'SEA', 'yearid': '2016', 'games': '12'}
# Created appearances =  null
# {'playerid': 'zychto01', 'teamid': 'SEA', 'yearid': '2017', 'games': '45'}
# Created appearances =  null
# Loaded  11455 records.

# %% [markdown]
# #### Probe the Data

# %%
r = fg.get_roster('BOS', 2016)
rr = pd.DataFrame(r.data())
rr
# Out:
#     a.games  a.year p.first_name p.last_name p.player_id t.team_id     t.team_name
# 0        33    2016         Brad     Ziegler   zieglbr01       BOS  Boston Red Sox
# 1        76    2016        Chris       Young   youngch04       BOS  Boston Red Sox
# 2        25    2016       Steven      Wright   wrighst01       BOS  Boston Red Sox
# 3        57    2016    Christian     Vazquez   vazquch01       BOS  Boston Red Sox
# 4        50    2016         Koji      Uehara   ueharko01       BOS  Boston Red Sox
# 5        53    2016      Junichi      Tazawa   tazawju01       BOS  Boston Red Sox
# 6        19    2016        Blake     Swihart   swihabl01       BOS  Boston Red Sox
# 7         3    2016       Carson       Smith   smithca02       BOS  Boston Red Sox
# 8       145    2016       Travis        Shaw    shawtr01       BOS  Boston Red Sox
# 9         7    2016        Robby       Scott   scottro02       BOS  Boston Red Sox
# 10        3    2016        Pablo    Sandoval   sandopa01       BOS  Boston Red Sox
# 11       28    2016         Josh    Rutledge   rutlejo01       BOS  Boston Red Sox
# 12       54    2016       Robbie        Ross    rossro01       BOS  Boston Red Sox
# 13       20    2016      Eduardo   Rodriguez   rodried05       BOS  Boston Red Sox
# 14       14    2016          Noe     Ramirez   ramirno01       BOS  Boston Red Sox
# 15      147    2016       Hanley     Ramirez   ramirha01       BOS  Boston Red Sox
# 16       35    2016        David       Price   priceda01       BOS  Boston Red Sox
# 17       33    2016         Rick    Porcello   porceri01       BOS  Boston Red Sox
# 18       14    2016         Drew    Pomeranz   pomerdr01       BOS  Boston Red Sox
# 19      154    2016       Dustin     Pedroia   pedrodu01       BOS  Boston Red Sox
# 20        5    2016        Henry       Owens   owenshe02       BOS  Boston Red Sox
# 21        5    2016         Sean  O'Sullivan   osullse01       BOS  Boston Red Sox
# 22      151    2016        David       Ortiz   ortizda01       BOS  Boston Red Sox
# 23        8    2016         Yoan     Moncada   moncayo01       BOS  Boston Red Sox
# 24        1    2016         Mike      Miller   millemi01       BOS  Boston Red Sox
# 25        4    2016      Michael    Martinez   martimi02       BOS  Boston Red Sox
# 26       13    2016        Deven     Marrero   marrede01       BOS  Boston Red Sox
# 27        2    2016          Pat       Light   lightpa01       BOS  Boston Red Sox
# 28       78    2016        Sandy        Leon    leonsa01       BOS  Boston Red Sox
# 29       34    2016        Tommy       Layne   layneto01       BOS  Boston Red Sox
# 30        6    2016         Ryan     LaMarre   lamarry01       BOS  Boston Red Sox
# 31       57    2016        Craig     Kimbrel   kimbrcr01       BOS  Boston Red Sox
# 32       20    2016          Joe       Kelly   kellyjo05       BOS  Boston Red Sox
# 33       94    2016        Brock        Holt    holtbr01       BOS  Boston Red Sox
# 34       14    2016        Bryan     Holaday   holadbr01       BOS  Boston Red Sox
# 35       47    2016        Aaron        Hill    hillaa01       BOS  Boston Red Sox
# 36       40    2016        Marco   Hernandez   hernama02       BOS  Boston Red Sox
# 37       38    2016        Heath     Hembree   hembrhe01       BOS  Boston Red Sox
# 38       35    2016         Ryan     Hanigan   hanigry01       BOS  Boston Red Sox
# 39        3    2016       Roenis       Elias   eliasro01       BOS  Boston Red Sox
# 40        3    2016      William      Cuevas   cuevawi01       BOS  Boston Red Sox
# 41        9    2016       Rusney    Castillo   castiru01       BOS  Boston Red Sox
# 42       37    2016         Clay    Buchholz   buchhcl01       BOS  Boston Red Sox
# 43       25    2016        Bryce      Brentz   brentbr01       BOS  Boston Red Sox
# 44      156    2016       Jackie     Bradley   bradlja02       BOS  Boston Red Sox
# 45       18    2016     Fernando        Abad    abadfe01       BOS  Boston Red Sox
# 46       62    2016         Matt      Barnes   barnema01       BOS  Boston Red Sox
# 47       34    2016       Andrew  Benintendi   beninan01       BOS  Boston Red Sox
# 48      158    2016       Mookie       Betts   bettsmo01       BOS  Boston Red Sox
# 49      157    2016       Xander    Bogaerts   bogaexa01       BOS  Boston Red Sox

# %%
def load_fans():
    fg.create_fan(uni="js1", last_name="Smith", first_name="John")
    fg.create_fan(uni="ja1", last_name="Adams", first_name="John")
    fg.create_fan(uni="tj1", last_name="Jefferson", first_name="Thomas")
    fg.create_fan(uni="gw1", last_name="Washing", first_name="George")
    fg.create_fan(uni="jm1", last_name="Monroe", first_name="James")
    fg.create_fan(uni="al1", last_name="Lincoln", first_name="Abraham")


def load_follows_fans():


    fg.create_follows(follower="gw1", followed="js1")
    fg.create_follows(follower="tj1", followed="gw1")
    fg.create_follows(follower="ja1", followed="gw1")
    fg.create_follows(follower="jm1", followed="gw1")
    fg.create_follows(follower="tj1", followed="gw1")
    fg.create_follows(follower="al1", followed="jm1")


def create_supports():

    fg.create_supports("gw1", "WAS")
    fg.create_supports("ja1", "BOS")
    fg.create_supports("tj1", "WAS")
    fg.create_supports("jm1", "NYA")
    fg.create_supports("al1", "CHA")
    fg.create_supports("al1", "CHN")

# %%
load_fans()

# %%
load_follows_fans()

# %%
create_supports()

# %% [markdown]
# ### Some Sample Tests

# %% [markdown]
# #### Comments
#
# | ![image.png](attachment:image.png) |
# | :---: |
# | __No Comments up my Sleeve__ |

# %%
def test_create_comment():
    # John Adams was from Boston. We would think that the Sox and Pedroia are awesome, if he were not dead.
    c = fg.create_comment("ja1", "Awesome", team_id="BOS", player_id="pedrodu01")
    print(c)

# %%
test_create_comment()
# Out:
# (_71733:Comment {comment: 'Awesome', comment_id: 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9'})

# %% [markdown]
# - Use the explore to see if it is there.

# %% [markdown]
# | ![image.png](attachment:image.png) |
# | :---: |
# | __Comment Created__ |

# %%
def test_get_player_comments():
    g = fg.get_player_comments("pedrodu01")
    print(g)
    g = g.data()

    return g

# %%
c = test_get_player_comments()
c
# Out:
# <py2neo.database.Cursor object at 0x1099b06a0>
# [{'comment.comment': 'Awesome',
#   'comment.comment_id': 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9',
#   'fan.first_name': 'John',
#   'fan.last_name': 'Adams',
#   'fan.uni': 'ja1',
#   'player.first_name': 'Dustin',
#   'player.last_name': 'Pedroia',
#   'player.player_id': 'pedrodu01'}]

# %%
# Make another comment from another person.
c = fg.create_comment("gw1", "Totally", "BOS", "pedrodu01")

# %% [markdown]
# - The graph now looks like ...
#
#
# | ![image.png](attachment:image.png) |
# | :---: |
# | __Created__ |

# %%
c = test_get_player_comments()
c
# Out:
# <py2neo.database.Cursor object at 0x109967208>
# [{'comment.comment': 'Totally',
#   'comment.comment_id': '212052c3-ce7c-453c-8c2f-07d942edebff',
#   'fan.first_name': 'George',
#   'fan.last_name': 'Washing',
#   'fan.uni': 'gw1',
#   'player.first_name': 'Dustin',
#   'player.last_name': 'Pedroia',
#   'player.player_id': 'pedrodu01'},
#  {'comment.comment': 'Awesome',
#   'comment.comment_id': 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9',
#   'fan.first_name': 'John',
#   'fan.last_name': 'Adams',
#   'fan.uni': 'ja1',
#   'player.first_name': 'Dustin',
#   'player.last_name': 'Pedroia',
#   'player.player_id': 'pedrodu01'}]

# %% [markdown]
# - Team comments

# %%
# My base function simple returns a RelationshipMatch
c = fg.get_team_comments('BOS')
print(c, "\n\n")

# This is kind of kooky. So, we need to unwind it.
# Let's see the whole structure. Start be seeing what is in the result set,
for r in c:
    print(r)

print("\n\nOK. A bunch of relationships")
# Out:
# <py2neo.matching.RelationshipMatch object at 0x1099b0a90>
#
#
# (_71734)-[:COMMENT_ON {}]->(_24669)
# (_71733)-[:COMMENT_ON {}]->(_24669)
# (_71734)-[:COMMENT_ON {}]->(_71701)
# (_71733)-[:COMMENT_ON {}]->(_71701)
# (_71733)-[:COMMENT_ON {}]->(_71701)
# (_71733)-[:COMMENT_ON {}]->(_24669)
# (_71734)-[:COMMENT_ON {}]->(_24669)
# (_71734)-[:COMMENT_ON {}]->(_71701)
#
#
# OK. A bunch of relationships

# %%
# Relationships have start and end nodes. Let's take a look.
# This is kind of kooky. So, we need to unwind it.
# Let's see the whole structure. Start be seeing what is in the result set,
for r in c:
    print("Start = ", r.start_node)
    print("End = ", r.end_node)
    print("\n")
# Out:
# Start =  (_71734:Comment {comment: 'Totally', comment_id: '212052c3-ce7c-453c-8c2f-07d942edebff'})
# End =  (_24669:Player {first_name: 'Dustin', last_name: 'Pedroia', player_id: 'pedrodu01'})
#
#
# Start =  (_71733:Comment {comment: 'Awesome', comment_id: 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9'})
# End =  (_24669:Player {first_name: 'Dustin', last_name: 'Pedroia', player_id: 'pedrodu01'})
#
#
# Start =  (_71734:Comment {comment: 'Totally', comment_id: '212052c3-ce7c-453c-8c2f-07d942edebff'})
# End =  (_71701:Team {team_id: 'BOS', team_name: 'Boston Red Sox'})
#
#
# Start =  (_71733:Comment {comment: 'Awesome', comment_id: 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9'})
# End =  (_71701:Team {team_id: 'BOS', team_name: 'Boston Red Sox'})
#
#
# Start =  (_71733:Comment {comment: 'Awesome', comment_id: 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9'})
# End =  (_71701:Team {team_id: 'BOS', team_name: 'Boston Red Sox'})
#
#
# Start =  (_71733:Comment {comment: 'Awesome', comment_id: 'eca3f196-e9cc-46de-b7f5-4d9a77db5dd9'})
# End =  (_24669:Player {first_name: 'Dustin', last_name: 'Pedroia', player_id: 'pedrodu01'})
#
#
# Start =  (_71734:Comment {comment: 'Totally', comment_id: '212052c3-ce7c-453c-8c2f-07d942edebff'})
# End =  (_24669:Player {first_name: 'Dustin', last_name: 'Pedroia', player_id: 'pedrodu01'})
#
#
# Start =  (_71734:Comment {comment: 'Totally', comment_id: '212052c3-ce7c-453c-8c2f-07d942edebff'})
# End =  (_71701:Team {team_id: 'BOS', team_name: 'Boston Red Sox'})

# %%
# OK. We can massage this into something a little cleaner.   
result = {}
for r in c:
    s = r.start_node
    e = r.end_node
    cid = s['comment_id']
    this_c = result.get(cid, None)
    if this_c is None:
        this_c = {}
        this_c['comment'] = s['comment']
       
    if "Team" in e.labels:
        this_c['team']=e['team_name']
    elif "Player" in e.labels:
        this_c['player'] = e['last_name'] + "," + e['first_name']
  
    result[cid] = this_c

final_result = []
for k,v in result.items():
    new_r = {}
    new_r["id"] = k
    new_r = {**new_r, **v}
    final_result.append(new_r)

df2 = pd.DataFrame(final_result)
print("\n\nAnd a data frame holding the result is ...\n")
print(df2)
# Out:
# And a data frame holding the result is ...
#
#    comment                                    id          player            team
# 0  Totally  212052c3-ce7c-453c-8c2f-07d942edebff  Pedroia,Dustin  Boston Red Sox
# 1  Awesome  eca3f196-e9cc-46de-b7f5-4d9a77db5dd9  Pedroia,Dustin  Boston Red Sox

# %% [markdown]
# ## Redis $-$ HW4 Part 2
#
# ### Concept
#
# - One of the most common uses of Redis is as a web response or API cache.
#
# | ![image.png](attachment:image.png) |
# | :---: |
# | SQL Result Cache |

# %% [markdown]
# |  ![image.png](attachment:image.png)|
# | :---: |
# | DB Cache in Web Application Flow |
#
# - HW4 will use Redis to implement a simple result cache in front of $retrieve\_by\_template().$

# %% [markdown]
# ### Starting Code

# %%
import redis
from operator import itemgetter
import json

"""
Connect to local Redis server. StrictRedis complies more closely with standard than
simple Redis client in this package. decode_responses specifies whether or not to convert
bytes to UTF8 character string or treat as raw bytes, e.g. an image, audio stream, etc.
"""
r = redis.StrictRedis(
    host='localhost',
    port=6379,
    charset="utf-8", decode_responses=True)


def add_to_cache(key, value):
    """

    :param key: A valid Redis key string.
    :param value: A Python dictionary to add to cache.
    :return: None
    """
    k = key
    #ut.debug_message("Adding key = ", k)
    #ut.debug_message("Adding data", value)
    r.set(k, value)


def get_from_cache(key):
    """

    :param key: A valid Redis key.
    :return: The "map object" associated with the key.
    """
    result = r.get(key)
    return result

def get_keys():
    result = r.keys()
    return result

def save_dict(k, d):
    result = r.hmset(k, d)
    return result

def get_dict(k):
    result = r.hgetall(k)
    return result

# %% [markdown]
# - Tests

# %%
get_keys()
# Out:
# ['responses:545228be-bbdb-464c-acf8-c92681b0b17f',
#  'some.dude@ansys.com:canary:1ac4d6ae-b0a1-48dd-a391-440f5b956b42',
#  'Batting:teamID=BOS,yearID=2004,playerID=ortizda01,f=AB,H,HR,RBI,playerID',
#  'blob:a145e5b3-9212-47d8-a823-888ba9edd669',
#  'donald.ferguson@ansys.com:banana:8350c932-a9dd-45fe-9b48-714a19fff271',
#  'People:nameLast=Williams,birthCity=San Diego,f=nameFirst,nameLast,playerID,throws',
#  'cool',
#  'responses:7d14c3df-9ff1-4d19-867b-cbeff04effe1',
#  'Person:Student:poma2',
#  'some.dude@ansys.com:mouse:1de5fa66-fbad-416a-b3b7-cce64ca4652e',
#  'actor:tom_hanks',
#  'donald.ferguson@ansys.com:mouse:e6ecf59e-a1ca-489b-ace0-52536b694699',
#  'Person:Student:poma1',
#  'blob:f6d9b168-6895-4e54-80b6-49f03d596350',
#  'responses:1a7adddd-e9b4-4100-bf6a-2ab4079ac80d',
#  'blob:a9501657-466e-4e6d-823b-7a0e75fe51b3',
#  'Person:Faculty:fedo1',
#  'Advises:fedo1',
#  'some.dude@ansys.com:elk:dd41f5c6-49e5-4fb4-8274-7ffc3ed3b98c',
#  'actor:tom_hanks:movies']

# %%
d = {"playerID": "cool", "title": "Imaginary"}

# %%
save_dict("2cool", d)
# Out:
# True

# %% [markdown]
# ### Homework

# %% [markdown]
# - HW4 will add checking the Redis cache to a simple, standalone $retrieve\_by\_template()$ function.
#     1. Write a function $add\_to\_cache()$ that adds a retrieve result to the cache.
#     2. Write a function $retrieve\_from\_cache()$ that checks the cache and returns the value if present.
#     3. Modify $retrieve\_by\_template()$ to use the cache.
#         1. Check and return if cached.
#         2. Call DB and add to cache if not cached.
#
#
# ### Some Helper Code
#
#
# - Some helper code

# %%
raise NotImplementedError("Just to get you started. Do not run.")

import pymysql.cursors
import json
import copy
import redis_cache.data_cache as dc


db_schema = None                                # Schema containing accessed data
cnx = None                                      # DB connection to use for accessing the data.
key_delimiter = '_'                             # This should probably be a config option.


def set_config():
    """
    Creates the DB connection and sets the global variables.

    :param cfg: Application configuration data.
    :return: None
    """
    global db_schema
    global cnx

    db_params = {
        "dbhost": "localhost",
        "port": 3306,
        "dbname": "lahman2017",
        "dbuser": "dbuser",
        "dbpw": "dbuserdbuser",
        "cursorClass": pymysql.cursors.DictCursor,
        "charset": 'utf8mb4'
    }

    db_schema = "lahman2017"

    cnx = db.get_new_connection(db_params)


# Given one of our magic templates, forms a WHERE clause.
# { a: b, c: d } --> WHERE a=b and c=d. Currently treats everything as a string.
# We can fix this by using PyMySQL connector query templates.
def templateToWhereClause(t):
    s = ""
    for k,v in t.items():
        if s != "":
            s += " AND "
        s += k + "='" + v + "'"

    if s != "":
        s = "WHERE " + s;

    return s

# %%
raise NotImplementedError("Just to get you started. Do not run.")

def run_q(cnx, q, args, fetch=False, commit=True):
    """
    :param cnx: The database connection to use.
    :param q: The query string to run.
    :param args: Parameters to insert into query template if q is a template.
    :param fetch: True if this query produces a result and the function should perform and return fetchall()
    :return:
    """
    #debug_message("run_q: q = " + q)
    #ut.debug_message("Q = " + q)
    #ut.debug_message("Args = ", args)

    result = None

    try:
        cursor = cnx.cursor()
        result = cursor.execute(q, args)
        if fetch:
            result = cursor.fetchall()
        if commit:
            cnx.commit()
    except pymysql_exceptions as original_e:
        #print("dffutils.run_q got exception = ", original_e)
        raise(original_e)

    return result

# %%
raise NotImplementedError("Just to get you started. Do not run.")

def retrieve_by_template(table, t, fields=None, limit=None, offset=None, orderBy=None, use_cache=False):


    original_fields = fields

    if t is not None:
        w = templateToWhereClause(t)
    else:
        w = ""

    if orderBy is not None:
        o = "order by " + ",".join(orderBy['fields']) + " " + orderBy['direction'] + " "
    else:
        o = ""

    if limit is not None:
        w += " LIMIT " + str(limit)
    if offset is not None:
        w += " OFFSET " + str(offset)

    if fields is None:
        fields = " * "
    else:
        fields = " " + ",".join(fields) + " "

    cursor=cnx.cursor()
    q = "SELECT " + fields + " FROM " + table + " " + w + ";"

    r = run_q(cnx, q, None, fetch=True, commit=True)

    return r

# %%
raise NotImplementedError("Just to get you started. Do not run.")

def check_cache(table, tmp, fields, limit, offset, orderBy):
    pass


def add_to_cache(table, tmp, fields, limit, offset, orderBy, q_result):
    pass

# %% [markdown]
# #### Some Test Code
#
# - Switching to my super secret implementation.

# %%
import sys
sys.path.append(
    '/Users/donaldferguson/Dropbox/ColumbiaCourse/Courses/W4111New/w4111-Databases/HW_Solutions/HW4')

# %%
from redis_cache import data_cache
from utils import utils as ut
from dbservice import dataservice as ds
import json

ut.set_debug_mode(True)
ds.set_config()

# %%
tmp = { "nameLast": "Williams", "birthState": "CA"}
fields = ["playerID", "nameLast", "nameFirst", "throws"]
resource = "People"


result = ds.retrieve_by_template(resource, tmp, fields, use_cache=True)
# Out:
# Check cache returned  None
#
# CACHE MISS

# %%
result = ds.retrieve_by_template(resource, tmp, fields, use_cache=True)
# Out:
# Check cache returned  [{'playerID': 'willibe01', 'nameLast': 'Williams', 'nameFirst': 'Bernie', 'throws': 'R'}, {'playerID': 'willido02', 'nameLast': 'Williams', 'nameFirst': 'Don', 'throws': 'R'}, {'playerID': 'williji03', 'nameLast': 'Williams', 'nameFirst': 'Jimy', 'throws': 'R'}, {'playerID': 'willike02', 'nameLast': 'Williams', 'nameFirst': 'Ken', 'throws': 'R'}, {'playerID': 'willima04', 'nameLast': 'Williams', 'nameFirst': 'Matt', 'throws': 'R'}, {'playerID': 'willimi02', 'nameLast': 'Williams', 'nameFirst': 'Mitch', 'throws': 'L'}, {'playerID': 'williri02', 'nameLast': 'Williams', 'nameFirst': 'Rinaldo', 'throws': 'R'}, {'playerID': 'williri03', 'nameLast': 'Williams', 'nameFirst': 'Rick', 'throws': 'R'}, {'playerID': 'willish01', 'nameLast': 'Williams', 'nameFirst': 'Shad', 'throws': 'R'}, {'playerID': 'willite01', 'nameLast': 'Williams', 'nameFirst': 'Ted', 'throws': 'R'}, {'playerID': 'willitr01', 'nameLast': 'Williams', 'nameFirst': 'Trevor', 'throws': 'R'}]
#
# CACHE HIT
